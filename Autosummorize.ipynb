# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook"

# %%
page = urlopen(url).read().decode('utf8','ignore') 
soup = BeautifulSoup(page,"lxml")
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]><html class="ie ie6 " lang="en"> <![endif]--><!--[if IE 7 ]><html class="ie ie7  " lang="en"> <![endif]--><!--[if IE 8 ]><html class="ie ie8  " lang="en"> <![endif]--><!--[if IE 9 ]><html class="ie ie9  " lang="en"> <![endif]--><!--[if (gte IE 9)|!(IE)]><!--><html class="" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="" name="description"/>
# <meta content="" name="author"/>
# <title>Removing Bad Actors on Facebook | Facebook Newsroom</title>
# <meta content="1908693766059395" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="https://fbnewsroomus.files.wordpress.com/2018/07/security1.png?w=960" property="og:image"/>
# <meta content="Removing Bad Actors on Facebook | Facebook Newsroom" property="og:title"/>
# <meta content="We removed 32 Pages and accounts from Facebook and Instagram because they were involved in coordinated inauthentic behavior. " property="og:description"/>
# <meta content="https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/" property="og:url"/>
# <!--[if lte IE 8]>
# 		  <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.6.2/html5shiv.js"></script>
# 		<![endif]-->
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://newsroom.fb.com/xmlrpc.php" rel="pingback"/>
# <link href="https://newsroom.fb.com/feed/" rel="alternate" title="Facebook Newsroom Feed" type="application/rss+xml"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/fb-newsroom/assets/bin/images/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/fb-newsroom/assets/bin/images/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/fb-newsroom/assets/bin/images/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/fb-newsroom/assets/bin/images/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/fb-newsroom/assets/bin/images/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/fb-newsroom/assets/bin/images/favicon.ico" rel="shortcut icon"/>
# <script src="https://r-login.wordpress.com/remote-login.php?action=js&amp;host=newsroom.fb.com&amp;id=62624316&amp;t=1533062587&amp;back=https%3A%2F%2Fnewsroom.fb.com%2Fnews%2F2018%2F07%2Fremoving-bad-actors-on-facebook%2F" type="text/javascript"></script>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 			if ( 'function' === typeof WPRemoteLogin ) {
# 				document.cookie = "wordpress_test_cookie=test; path=/";
# 				if ( document.cookie.match( /(;|^)\s*wordpress_test_cookie\=/ ) ) {
# 					WPRemoteLogin();
# 				}
# 			}
# 		/* ]]> */
# 		</script>
# <link href="//s2.wp.com" rel="dns-prefetch"/>
# <link href="//s1.wp.com" rel="dns-prefetch"/>
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//fbnewsroomus.wordpress.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s0.wp.com\/wp-includes\/js\/wp-emoji-release.min.js?m=1532082729h&ver=4.9.8-RC2-43539"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://s2.wp.com/_static/??-?cssminify=yes" id="all-css-0-1" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wpcom_geo_settings = {"geolocation_endpoint":"https:\/\/public-api.wordpress.com\/geo\/","locations":["br","us","de","es","fr","ja","jp","ko","kr","ltam","ar","bo","cl","co","cr","cu","do","ec","sv","gt","ht","hn","mx","ni","pa","pe","pr","uy","ve","us"],"default_location":"us","cookie_name":"_wpcom_geo","expiry_date":"Tue, 07 Aug 2018 18:43:07 UTC","expiry_time":"604800","domain":".newsroom.fb.com","cookie_notice_name":"_fbnr_geo_notice","site_country":"us","show_redirect_notice":"1"};
# /* ]]> */
# </script>
# <script src="https://s0.wp.com/_static/??-eJydkN0KwjAMhV/IrtuF80p8lrVmNXNNa9NuuKe3kymIY4IQCOR8OfmRoxdIuk9nYNnluCUI9yUVHe/kFiAsmtBEKCzSC9aOIlCcWesU9iASQ2hMrmWj1q1w3nG0wJyhFfVzJaQBYfyJdRB9o68iAOP05RovkOfJAb30fTJInFXtrDDgRCLMHs9j38UNg1YJgpGDc1Y2zBBZKqS5+9++HlV+3RkC4RSW157ssdqXVVXX5aHuHgz1o6Q=" type="text/javascript"></script>
# <link href="https://fbnewsroomus.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://s1.wp.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress.com" name="generator"/>
# <link href="http://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/" rel="canonical"/>
# <link href="https://wp.me/p4eLrC-36v" rel="shortlink"/>
# <link href="https://public-api.wordpress.com/oembed/?format=json&amp;url=https%3A%2F%2Fnewsroom.fb.com%2Fnews%2F2018%2F07%2Fremoving-bad-actors-on-facebook%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/json+oembed"/><link href="https://public-api.wordpress.com/oembed/?format=xml&amp;url=https%3A%2F%2Fnewsroom.fb.com%2Fnews%2F2018%2F07%2Fremoving-bad-actors-on-facebook%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/xml+oembed"/><link href="https://fbnewsroomus.wordpress.com/?openidserver=1" rel="openid.server"/>
# <link href="https://fbnewsroomus.wordpress.com/" rel="openid.delegate"/>
# <link href="https://newsroom.fb.com/osd.xml" rel="search" title="Facebook Newsroom" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <meta content="20531316728" property="fb:pages"/>
# <meta content="https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/?ia_markup=1" property="ia:markup_url"/>
# <style>
# 			.wpcom-related-posts ul li {
# 				list-style-type: none;
# 				display: inline-block;
# 			}
# 		</style>
# <style type="text/css">.recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}</style>
# <style type="text/css">
# 			.recentcomments a {
# 				display: inline !important;
# 				padding: 0 !important;
# 				margin: 0 !important;
# 			}
#
# 			table.recentcommentsavatartop img.avatar, table.recentcommentsavatarend img.avatar {
# 				border: 0px;
# 				margin: 0;
# 			}
#
# 			table.recentcommentsavatartop a, table.recentcommentsavatarend a {
# 				border: 0px !important;
# 				background-color: transparent !important;
# 			}
#
# 			td.recentcommentsavatarend, td.recentcommentsavatartop {
# 				padding: 0px 0px 1px 0px;
# 				margin: 0px;
# 			}
#
# 			td.recentcommentstextend {
# 				border: none !important;
# 				padding: 0px 0px 2px 10px;
# 			}
#
# 			.rtl td.recentcommentstextend {
# 				padding: 0px 10px 2px 0px;
# 			}
#
# 			td.recentcommentstexttop {
# 				border: none;
# 				padding: 0px 0px 0px 10px;
# 			}
#
# 			.rtl td.recentcommentstexttop {
# 				padding: 0px 10px 0px 0px;
# 			}
# 		</style>
# <meta content="Facebook Newsroom" name="application-name"/><meta content="width=device-width;height=device-height" name="msapplication-window"/><meta content="name=Subscribe;action-uri=https://newsroom.fb.com/feed/;icon-uri=https://secure.gravatar.com/blavatar/afc121cc2580b79a105cf9c7edfa7720?s=16" name="msapplication-task"/><link href="https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/amp/" rel="amphtml"/><style id="syntaxhighlighteranchor" type="text/css"></style>
# <!-- Oswald Font -->
# <link href="https://fonts.googleapis.com/css?family=Oswald:300,400,500,600,700" rel="stylesheet"/>
# <!-- Facebook Pixel Code -->
# <script>
# 		  !function(f,b,e,v,n,t,s)
# 		  {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 		  n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# 		  if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# 		  n.queue=[];t=b.createElement(e);t.async=!0;
# 		  t.src=v;s=b.getElementsByTagName(e)[0];
# 		  s.parentNode.insertBefore(t,s)}(window, document,'script',
# 		  'https://connect.facebook.net/en_US/fbevents.js');
# 		  fbq('init', '1040658402776500');
# 		  fbq('track', 'PageView');
# 		</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1040658402776500&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# </head>
# <body class="post-template-default single single-post postid-11935 single-format-standard mp6 customizer-styles-applied group-blog post-removing-bad-actors-on-facebook country-us locale-en highlander-enabled highlander-light">
# <!--
# 			Locale: en			Country: us		-->
# <div id="fb-root"></div>
# <script>
# 		window.fbAsyncInit = function() {
# 			FB.init({
# 				appId      : "1908693766059395",
# 				xfbml      : true,
# 				version    : 'v2.9'
# 			});
#
# 			FB.Event.subscribe('xfbml.ready', function(msg) {
# 			  if (msg.type === 'video' && msg.id === 'ff_video') {
# 				 fb_video_player = msg.instance;
# 			  }
# 			});
# 		};
#
# 		(function(d, s, id){
# 			var js, fjs = d.getElementsByTagName(s)[0];
# 			if (d.getElementById(id)) {return;}
# 			js = d.createElement(s); js.id = id;
# 			js.src = "\/\/connect.facebook.net\/en_US\/all.js";
# 			fjs.parentNode.insertBefore(js, fjs);
# 		}(document, 'script', 'facebook-jssdk'));
# 	</script>
# <script>
# 			// Google Analytics
# 			(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 				(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 				m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 			})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 			ga('create', 'UA-47542077-1', 'auto');
# 			ga('create', 'UA-47542077-14', 'auto', {'name': 'localeTracker'});
# 			ga('send', 'pageview');
# 			ga('localeTracker.send', 'pageview');
#
# 		</script>
# <header id="header-primary">
# <div class="wrapper clearfix" id="header-1">
# <div id="logo">
# <a href="http://www.facebook.com" id="logo-icon" title="Facebook Home">
# <img alt="" height="28" src="https://s2.wp.com/wp-content/themes/vip/fb-newsroom/assets/bin/images/logo-fb-2x.png" width="28"/>
# </a>
# <a href="https://newsroom.fb.com/" id="logo-text">Facebook Newsroom</a>
# </div>
# <span id="primary-menu-toggle">Menu</span>
# </div><!--end:.wrapper-->
# <div id="header-2">
# <nav class="wrapper">
# <div class="search-box">
# <form action="https://newsroom.fb.com/" method="get">
# <label for="search">
# <span>Search in newsroom</span>
# </label>
# <input id="search" name="s" placeholder="Search in newsroom" type="text" value=""/>
# <input name="post_type" type="hidden" value=""/>
# <button type="submit"></button>
# </form>
# </div><!--end:.search-box-->
# <ul>
# <li class=""><a href="https://newsroom.fb.com/home">Home</a></li>
# <li class="current-menu-item"><a class="" href="https://newsroom.fb.com/news/">News</a></li>
# <li class=""><a class="" href="https://newsroom.fb.com/company-info/">Company Info</a></li>
# <!--<li class="current-menu-item"><a class="" href=""></a></li>-->
# <li class=""><a class="" href="https://newsroom.fb.com/news/category/inside-feed/">Inside Feed</a></li>
# <li class=""><a class="" href="https://newsroom.fb.com/pages-directory/">Directory</a></li>
# <li class=""><a class="" href="https://newsroom.fb.com/media-gallery/">Media Gallery</a></li>
# <li><a class="" href="http://investor.fb.com/">Investor Relations</a></li>
# </ul>
# </nav>
# </div><!--end:.wrapper-->
# </header><!--end:.header-primary-->
# <div class="wrapper">
# <section class="two-columns clearfix">
# <div class="secondary-content narrow">
# <div class="responsive-nav">
# <form class="clearfix">
# <div class="custom-select" id="sel-category">
# <select class="chosen-select" name="sel-category">
# <option value="">Select category</option>
# <option value="https://newsroom.fb.com/news/category/company-news/">
# 										Company News									</option>
# <option value="https://newsroom.fb.com/news/category/product-news/">
# 										Product News									</option>
# <option value="https://newsroom.fb.com/news/category/hard-questions/">
# 										Hard Questions									</option>
# <option value="https://newsroom.fb.com/news/category/inside-feed/">
# 										Inside Feed									</option>
# <option value="https://newsroom.fb.com/news/category/measurement-fyi/">
# 										Measurement FYI									</option>
# <option value="https://newsroom.fb.com/news/category/community-boost/">
# 										Community Boost									</option>
# </select>
# </div>
# <div class="custom-select" id="sel-year">
# <select class="chosen-select" name="sel-year">
# <option value="">Select year</option>
# <option value="https://newsroom.fb.com/news/2018">2018</option>
# <option value="https://newsroom.fb.com/news/2017">2017</option>
# <option value="https://newsroom.fb.com/news/2016">2016</option>
# <option value="https://newsroom.fb.com/news/2015">2015</option>
# <option value="https://newsroom.fb.com/news/2014">2014</option>
# <option value="https://newsroom.fb.com/news/2013">2013</option>
# <option value="https://newsroom.fb.com/news/2012">2012</option>
# <option value="https://newsroom.fb.com/news/2011">2011</option>
# <option value="https://newsroom.fb.com/news/2010">2010</option>
# <option value="https://newsroom.fb.com/news/2009">2009</option>
# <option value="https://newsroom.fb.com/news/2008">2008</option>
# <option value="https://newsroom.fb.com/news/2007">2007</option>
# <option value="https://newsroom.fb.com/news/2006">2006</option>
# </select>
# </div>
# </form>
# </div>
# <aside class="no-card sidebar">
# <div class="sidebar-widget">
# <h2>Contact Us</h2>
# <p><a href="mailto:press@fb.com">press@fb.com</a></p>
# </div><!--end:.sidebar-widget-->
# <div class="sidebar-widget">
# <h2>Categories</h2>
# <ul>
# <li class=" menu-item-object-category ">
# <a href="https://newsroom.fb.com/news/category/company-news/">
# 										Company News									</a>
# </li>
# <li class=" menu-item-object-category ">
# <a href="https://newsroom.fb.com/news/category/product-news/">
# 										Product News									</a>
# </li>
# <li class=" menu-item-object-category ">
# <a href="https://newsroom.fb.com/news/category/hard-questions/">
# 										Hard Questions									</a>
# </li>
# <li class=" menu-item-object-category ">
# <a href="https://newsroom.fb.com/news/category/inside-feed/">
# 										Inside Feed									</a>
# </li>
# <li class=" menu-item-object-category ">
# <a href="https://newsroom.fb.com/news/category/measurement-fyi/">
# 										Measurement FYI									</a>
# </li>
# <li class=" menu-item-object-category ">
# <a href="https://newsroom.fb.com/news/category/community-boost/">
# 										Community Boost									</a>
# </li>
# </ul>
# </div><!--end:.sidebar-widget-->
# <div class="sidebar-widget">
# <h2>Archive</h2>
# <ul>
# <li><a href="https://newsroom.fb.com/news/2018">2018</a></li>
# <li><a href="https://newsroom.fb.com/news/2017">2017</a></li>
# <li><a href="https://newsroom.fb.com/news/2016">2016</a></li>
# <li><a href="https://newsroom.fb.com/news/2015">2015</a></li>
# <li><a href="https://newsroom.fb.com/news/2014">2014</a></li>
# <li><a href="https://newsroom.fb.com/news/2013">2013</a></li>
# <li><a href="https://newsroom.fb.com/news/2012">2012</a></li>
# <li><a href="https://newsroom.fb.com/news/2011">2011</a></li>
# <li><a href="https://newsroom.fb.com/news/2010">2010</a></li>
# <li><a href="https://newsroom.fb.com/news/2009">2009</a></li>
# <li><a href="https://newsroom.fb.com/news/2008">2008</a></li>
# <li><a href="https://newsroom.fb.com/news/2007">2007</a></li>
# <li><a href="https://newsroom.fb.com/news/2006">2006</a></li>
# </ul>
# </div><!--end:.sidebar-widget-->
# <div class="sidebar-widget featured-news">
# <h2>Featured News</h2>
# <div class="sidebar-featured-news-item">
# <a href="https://newsroom.fb.com/news/2018/07/diversity-report/">
# <img alt="" class="attachment-thumbnail size-thumbnail wp-post-image" data-attachment-id="11728" data-comments-opened="0" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="diversity report" data-large-file="https://fbnewsroomus.files.wordpress.com/2018/07/diversity-report.png?w=960" data-medium-file="https://fbnewsroomus.files.wordpress.com/2018/07/diversity-report.png?w=300" data-orig-file="https://fbnewsroomus.files.wordpress.com/2018/07/diversity-report.png" data-orig-size="2324,1220" data-permalink="https://newsroom.fb.com/news/2018/07/diversity-report/diversity-report-2/" height="315" sizes="(max-width: 600px) 100vw, 600px" src="https://fbnewsroomus.files.wordpress.com/2018/07/diversity-report.png?w=600" srcset="https://fbnewsroomus.files.wordpress.com/2018/07/diversity-report.png?w=600 600w, https://fbnewsroomus.files.wordpress.com/2018/07/diversity-report.png?w=1200 1200w, https://fbnewsroomus.files.wordpress.com/2018/07/diversity-report.png?w=300 300w, https://fbnewsroomus.files.wordpress.com/2018/07/diversity-report.png?w=768 768w, https://fbnewsroomus.files.wordpress.com/2018/07/diversity-report.png?w=1024 1024w" width="600"/> </a>
# <h3><a href="https://newsroom.fb.com/news/2018/07/diversity-report/">Facebook 2018 Diversity Report: Reflecting on Our Journey</a></h3>
# <p class="date">July 12, 2018</p>
# <div class="excerpt">
# <p>We’re publishing our fifth annual diversity report and sharing what we believe is working and where we can do…</p>
# <a class="read-more" href="https://newsroom.fb.com/news/2018/07/diversity-report/">Read more</a>
# </div>
# </div><!--end:.home-recent-news-item-->
# <div class="sidebar-featured-news-item">
# <a href="https://newsroom.fb.com/news/2018/06/hard-questions-fact-checking/">
# <img alt="" class="attachment-thumbnail size-thumbnail wp-post-image" data-attachment-id="11467" data-comments-opened="0" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="FactCheckers_Thumbnail_Final" data-large-file="https://fbnewsroomus.files.wordpress.com/2018/06/factcheckers_thumbnail_final.gif?w=960" data-medium-file="https://fbnewsroomus.files.wordpress.com/2018/06/factcheckers_thumbnail_final.gif?w=300" data-orig-file="https://fbnewsroomus.files.wordpress.com/2018/06/factcheckers_thumbnail_final.gif" data-orig-size="1000,563" data-permalink="https://newsroom.fb.com/news/2018/06/hard-questions-fact-checking/factcheckers_thumbnail_final/" height="338" sizes="(max-width: 600px) 100vw, 600px" src="https://fbnewsroomus.files.wordpress.com/2018/06/factcheckers_thumbnail_final.gif?w=600" srcset="https://fbnewsroomus.files.wordpress.com/2018/06/factcheckers_thumbnail_final.gif?w=600 600w, https://fbnewsroomus.files.wordpress.com/2018/06/factcheckers_thumbnail_final.gif?w=300 300w, https://fbnewsroomus.files.wordpress.com/2018/06/factcheckers_thumbnail_final.gif?w=768 768w, https://fbnewsroomus.files.wordpress.com/2018/06/factcheckers_thumbnail_final.gif 1000w" width="600"/> </a>
# <h3><a href="https://newsroom.fb.com/news/2018/06/hard-questions-fact-checking/">Hard Questions: How Is Facebook’s Fact-Checking Program Working?</a></h3>
# <p class="date">June 14, 2018</p>
# <div class="excerpt">
# <p>When fact-checkers rate an article as false, we show it lower in News Feed so fewer people see it….</p>
# <a class="read-more" href="https://newsroom.fb.com/news/2018/06/hard-questions-fact-checking/">Read more</a>
# </div>
# </div><!--end:.home-recent-news-item-->
# </div><!--end:.sidebar-widget-->
# </aside><!--end:.no-card--> </div>
# <div class="primary-content wide">
# <div class="card post article-single" id="post-11935">
# <div class="card-padding remove-padding-bottom">
# <header class="">
# <p class="date">July 31, 2018</p>
# <h1>Removing Bad Actors on Facebook</h1>
# </header>
# <div class="featured-image">
# <img alt="" class="attachment-large size-large wp-post-image" data-attachment-id="11940" data-comments-opened="0" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="security" data-large-file="https://fbnewsroomus.files.wordpress.com/2018/07/security1.png?w=960" data-medium-file="https://fbnewsroomus.files.wordpress.com/2018/07/security1.png?w=300" data-orig-file="https://fbnewsroomus.files.wordpress.com/2018/07/security1.png" data-orig-size="1362,850" data-permalink="https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/security/" height="599" sizes="(max-width: 960px) 100vw, 960px" src="https://fbnewsroomus.files.wordpress.com/2018/07/security1.png?w=960" srcset="https://fbnewsroomus.files.wordpress.com/2018/07/security1.png?w=960 960w, https://fbnewsroomus.files.wordpress.com/2018/07/security1.png?w=600 600w, https://fbnewsroomus.files.wordpress.com/2018/07/security1.png?w=300 300w, https://fbnewsroomus.files.wordpress.com/2018/07/security1.png?w=768 768w, https://fbnewsroomus.files.wordpress.com/2018/07/security1.png?w=1024 1024w, https://fbnewsroomus.files.wordpress.com/2018/07/security1.png 1362w" width="960"/> </div>
# </div><!--end:.card-padding-->
# <div class="card-padding remove-padding-top remove-padding-bottom hide-overflow">
# <div class="post-content">
# <p>Today we removed 32 Pages and accounts from Facebook and Instagram because they were involved in coordinated inauthentic behavior. This kind of behavior is not allowed on Facebook because we don’t want people or organizations creating networks of accounts to mislead others about who they are, or what they’re doing.</p>
# <p>We’re still in the very early stages of our investigation and don’t have all the facts — including who may be behind this. But we are sharing what we know today given the connection between these bad actors and protests that are planned in Washington next week. We will update this post with more details when we have them, or if the facts we have change.</p>
# <p>It’s clear that whoever set up these accounts went to much greater lengths to obscure their true identities than the Russian-based Internet Research Agency (IRA) has in the past. We believe this could be partly due to changes we’ve made over the last year to make this kind of abuse much harder. But security is not something that’s ever done. We face determined, well-funded adversaries who will never give up and are constantly changing tactics. It’s an arms race and we need to constantly improve too. It’s why we’re investing heavily in more people and better technology to prevent bad actors misusing Facebook — as well as working much more closely with law enforcement and other tech companies to better understand the threats we face.</p>
# <p><a href="#what-weve-found">What We’ve Found So Far</a><br/>
# <a href="#whos-behind-cyber-threats">How Much Can Companies Know About Who’s Behind Cyber Threats?</a><br/>
# <a href="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content1.zip">Sample Content</a></p>
# <p> </p>
# <p id="what-weve-found">July 31, 2018</p>
# <h1>What We’ve Found So Far</h1>
# <p><em>By <a href="https://www.facebook.com/ngleicher">Nathaniel Gleicher</a>, Head of Cybersecurity Policy</em></p>
# <p><b>About two weeks ago we identified the first of </b><b>eight </b><b>Pages and 17 profiles on Facebook, as well as seven Instagram accounts</b><b>, that violate our ban on coordinated inauthentic behavior</b><b>. </b>We removed all of them<b> </b>this morning once we’d completed our initial investigation and shared the information with US law enforcement agencies, Congress, other technology companies, and the <a href="https://newsroom.fb.com/news/2018/05/announcing-new-election-partnership-with-the-atlantic-council/">Atlantic Council</a><a href="https://newsroom.fb.com/news/2018/05/announcing-new-election-partnership-with-the-atlantic-council/">’s Digital Forensic Research Lab</a>, a research organization that helps us identify and analyze abuse on Facebook.</p>
# <ul>
# <li>In total, more than 290,000 accounts followed at least one of these Pages, the earliest of which was created in March 2017. The latest was created in May 2018.</li>
# <li>The most followed Facebook Pages were “Aztlan Warriors,” “Black Elevation,” “Mindful Being,” and “Resisters.” The remaining Pages had between zero and 10 followers, and the Instagram accounts had zero followers.</li>
# <li>There were more than 9,500 organic posts created by these accounts on Facebook, and one piece of content on Instagram.</li>
# <li>They ran about 150 ads for approximately $11,000 on Facebook and Instagram, paid for in US and Canadian dollars. The first ad was created in April 2017, and the last was created in June 2018.</li>
# <li>The Pages created about 30 events since May 2017. About half had fewer than 100 accounts interested in attending. The largest had approximately 4,700 accounts interested in attending, and 1,400 users said that they would attend.</li>
# </ul>
# <p>We are still reviewing all of the content and ads from these Pages. In the meantime <a href="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content1.zip">here are some examples</a> of the content and ads posted by these Pages.</p>
# <p><img alt="" class="size-large wp-image-11942 aligncenter" data-attachment-id="11942" data-comments-opened="0" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="sample content 1" data-large-file="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png?w=960&amp;h=645" data-medium-file="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png?w=300" data-orig-file="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png" data-orig-size="1039,698" data-permalink="https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/sample-content-1/" height="645" sizes="(max-width: 960px) 100vw, 960px" src="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png?w=960&amp;h=645" srcset="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png?w=960&amp;h=645 960w, https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png?w=595&amp;h=400 595w, https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png?w=300&amp;h=202 300w, https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png?w=768&amp;h=516 768w, https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png?w=1024&amp;h=688 1024w, https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-1.png 1039w" width="960"/></p>
# <p><b>These bad actors have been more careful to cover their tracks, in part due to the actions we’ve taken to prevent abuse over the past year. </b>For example they used<b> </b>VPNs and internet phone services, and paid third parties to run ads on their behalf. As we’ve told law enforcement and Congress, we still don’t have firm evidence to say with certainty who’s behind this effort<b>. </b>Some of the activity is consistent with what we saw from the IRA before and after the 2016 elections. And we’ve found evidence of some connections between these accounts and IRA accounts we disabled last year, which is covered below. But there are differences, too. For example, while IP addresses are easy to spoof, the IRA accounts we disabled last year sometimes used Russian IP addresses. We haven’t seen those here.</p>
# <p><b>We found this activity as part of our ongoing efforts to identify coordinated inauthentic behavior.</b> Given these bad actors are now working harder to obscure their identities, we need to find every small mistake they make. It’s why we’re following up on thousands of leads, including information from law enforcement and lessons we learned from last year’s IRA investigation. The IRA engaged with many legitimate Pages, so these leads sometimes turn up nothing. However, one of these leads did turn up something. One of the IRA accounts we disabled in 2017 shared a Facebook Event hosted by the “Resisters” Page. This Page also previously had an IRA account as one of its admins for only seven minutes. These discoveries helped us uncover the other inauthentic accounts we disabled today.</p>
# <p><img alt="" class="aligncenter size-full wp-image-11945" data-attachment-id="11945" data-comments-opened="0" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="sample content 2" data-large-file="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-2.png?w=960?w=939" data-medium-file="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-2.png?w=960?w=300" data-orig-file="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-2.png?w=960" data-orig-size="939,642" data-permalink="https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/sample-content-2/" sizes="(max-width: 939px) 100vw, 939px" src="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-2.png?w=960" srcset="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-2.png 939w, https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-2.png?w=585 585w, https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-2.png?w=300 300w, https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-2.png?w=768 768w"/></p>
# <p><b>The “Resisters” Page also created a Facebook Event for a protest on August 10 to 12 and enlisted support from real people. </b>The Event – “No Unite the Right 2 – DC” – was scheduled to protest an August “Unite the Right” event in Washington. Inauthentic admins of the “Resisters” Page connected with admins from five legitimate Pages to co-host the event. These legitimate Pages unwittingly helped build interest in “No Unite Right 2 – DC” and posted information about transportation, materials, and locations so people could get to the protests.</p>
# <p><img alt="" class="aligncenter size-full wp-image-11946" data-attachment-id="11946" data-comments-opened="0" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="sample content 3" data-large-file="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-3.png?w=960?w=510" data-medium-file="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-3.png?w=960?w=275" data-orig-file="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-3.png?w=960" data-orig-size="510,556" data-permalink="https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/sample-content-3/" sizes="(max-width: 510px) 100vw, 510px" src="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-3.png?w=960" srcset="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-3.png 510w, https://fbnewsroomus.files.wordpress.com/2018/07/sample-content-3.png?w=275 275w"/></p>
# <p><b>We disabled the event earlier today and have reached out to the admins of the five other Pages to update them on what happened</b>. This afternoon, we’ll begin informing the approximately 2,600 users interested in the event, and the more than 600 users who said they’d attend, about what happened.</p>
# <p><img alt="" class="aligncenter size-large wp-image-11956" data-attachment-id="11956" data-comments-opened="0" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="1 Action@2x" data-large-file="https://fbnewsroomus.files.wordpress.com/2018/07/1-action2x.png?w=960&amp;h=480" data-medium-file="https://fbnewsroomus.files.wordpress.com/2018/07/1-action2x.png?w=300" data-orig-file="https://fbnewsroomus.files.wordpress.com/2018/07/1-action2x.png" data-orig-size="1004,502" data-permalink="https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/1-action2x/" height="480" sizes="(max-width: 960px) 100vw, 960px" src="https://fbnewsroomus.files.wordpress.com/2018/07/1-action2x.png?w=960&amp;h=480" srcset="https://fbnewsroomus.files.wordpress.com/2018/07/1-action2x.png?w=960&amp;h=480 960w, https://fbnewsroomus.files.wordpress.com/2018/07/1-action2x.png?w=600&amp;h=300 600w, https://fbnewsroomus.files.wordpress.com/2018/07/1-action2x.png?w=300&amp;h=150 300w, https://fbnewsroomus.files.wordpress.com/2018/07/1-action2x.png?w=768&amp;h=384 768w, https://fbnewsroomus.files.wordpress.com/2018/07/1-action2x.png 1004w" width="960"/></p>
# <p><b>We don’t have all the facts, but we’ll work closely with others as we continue our investigation.</b> We hope to get new information from law enforcement and other companies so we can better understand what happened — and we’ll share any additional findings with law enforcement and Congress. However, we may never be able to identify the source with the same level of confidence we had in naming the IRA last year. See <a href="#whos-behind-cyber-threats">Alex Stamos’ post below</a> on why attribution can be really hard.</p>
# <p><b>We’re seeing real benefits from working with outside experts. </b>Partners like the Atlantic Council have provided invaluable help in identifying bad actors and analyzing their behavior across the internet. Based on leads from the recent US Department of Justice <a href="https://www.justice.gov/opa/pr/grand-jury-indicts-12-russian-intelligence-officers-hacking-offenses-related-2016-election">indictment</a>, the Atlantic Council identified a Facebook group with roughly 4,000 members. It was created by Russian government actors but had been dormant since we disabled the group’s admins last year. Groups typically persist on Facebook even when their admins are disabled, but we chose to remove this group to protect the privacy of its members in advance of a report that the Atlantic Council plans to publish as soon as it concludes its analysis. It will follow this report in the coming weeks with an analysis of the Pages, accounts and profiles we disabled today.</p>
# <p> </p>
# <p id="whos-behind-cyber-threats">July 31, 2018</p>
# <h1>How Much Can Companies Know About Who’s Behind Cyber Threats?</h1>
# <p><em>By <a href="https://www.facebook.com/alex.stamos">Alex Stamos</a>, Chief Security Officer</em></p>
# <p>Deciding when and how to publicly link suspicious activity to a specific organization, government, or individual is a challenge that governments and many companies face. Last year, we said the Russia-based Internet Research Agency (IRA) was behind much of the abuse we found around the 2016 election. But today we’re shutting down 32 Pages and accounts engaged in coordinated inauthentic behavior without saying that a specific group or country is responsible.</p>
# <p>The process of attributing observed activity to particular threat actors has been much debated by <a href="https://www.tandfonline.com/doi/pdf/10.1080/01402390.2014.977382?needAccess=true">academics</a> and within the <a href="https://www.dni.gov/files/PE/Documents/Cyber-Attribution.pdf">intelligence community</a>. All modern intelligence agencies use their own internal guidelines to help them consistently communicate their findings to policymakers and the public. Companies, by comparison, operate with relatively limited information from outside sources — though as we get more involved in detecting and investigating this kind of misuse, we also need clear and consistent ways to confront and communicate these issues head on.</p>
# <p><b>Determining Who is Behind an Action</b></p>
# <p>The first challenge is figuring out the type of entity to which we are attributing responsibility. This is harder than it might sound. It is standard for both traditional security attacks and information operations to be conducted using commercial infrastructure or computers belonging to innocent people that have been compromised. As a result, simple techniques like blaming the owner of an IP address that was used to register a malicious account usually aren’t sufficient to accurately determine who’s responsible.</p>
# <p>Instead, we try to:</p>
# <ul>
# <li>Link suspicious activity to the individual or group with <i>primary operational responsibility</i> for the malicious action. We can then potentially associate multiple campaigns to one set of actors, study how they abuse our systems, and take appropriate countermeasures.</li>
# <li>Tie a specific actor to a <i>real-world sponsor</i>. This could include a political organization, a nation-state, or a non-political entity.</li>
# </ul>
# <p>The relationship between malicious actors and real-world sponsors can be difficult to determine in practice, especially for activity sponsored by nation-states. In his <a href="http://www.atlanticcouncil.org/images/files/publication_pdfs/403/022212_ACUS_NatlResponsibilityCyber.PDF">seminal paper</a> on the topic, Jason Healey described a spectrum to measure the degree of state responsibility for cyber attacks. This included 10 discrete steps ranging from “state-prohibited,” where a state actively stops attacks originating from their territory, to “state-integrated,” where the attackers serve as fully integrated resources of the national government.</p>
# <p>This framework is helpful when looking at the two major organized attempts to interfere in the 2016 US election on Facebook that we have found to date. One set of actors used hacking techniques to steal information from email accounts — and then contacted journalists using social media to encourage them to publish stories about the stolen data. Based on our investigation and information provided by the US government, we concluded that this work was the responsibility of groups tied to the GRU, or Russian military intelligence. The recent Special Counsel indictment of GRU officers supports our assessment in this case, and we would consider these actions to be “state-integrated” on Healey’s spectrum.</p>
# <p>The other major organized effort did not include traditional cyber attacks but was instead designed to sow division using social media. Based on our own investigations, we assessed with high confidence that this group was part of the IRA. There has been a public debate about the relationship between the IRA and the Russian government — though most seem to conclude this activity is between “state-encouraged” and “state-ordered” using Healey’s definitions.</p>
# <p><b>Four Methods of Attribution</b></p>
# <p>Academics have written about a variety of methods for attributing activity to cyber actors, but for our purposes we simplify these methods into an attribution model with four general categories. And while all of these are appropriate for government organizations, we do not believe some of them should be used by companies:</p>
# <ul>
# <li><b>Political</b> <b>Motivations</b>: In this model, inferred political motivations are measured against the known political goals of a nation-state. Providing public attribution based on political evidence is especially challenging for companies because we don’t have the information needed to make this kind of evaluation. For example, we lack the analytical capabilities, signals intelligence, and human sources available to the intelligence community. As a result, we don’t believe it is appropriate for Facebook to give public comment on the political motivations of nation-states.</li>
# <li><b>Coordination</b>: Sometimes we will observe signs of coordination between threat actors even when the evidence indicates that they are operating separate technical infrastructure. We have to be careful, though, because coincidences can happen. Collaboration that requires sharing of secrets, such as the possession of stolen data before it has been publicly disclosed, should be treated as much stronger evidence than open interactions in public forums.</li>
# <li><b>Tools, Techniques and Procedures (TTPs)</b>: By looking at how a threat group performs their actions to achieve a goal — including reconnaissance, planning, exploitation, command and control, and exfiltration or distribution of information — it is often possible to infer a linkage between a specific incident and a known threat actor. We believe there is value in providing our assessment of how TTPs compare with previous events, but we don’t plan to rely solely upon TTPs to provide any direct attribution.</li>
# <li><b>Technical Forensics</b>: By studying the specific indicators of compromise (IOCs) left behind in an incident, it’s sometimes possible to trace activity back to a known or new organized actor. Sometimes these IOCs point to a specific group using shared software or infrastructure, or to a specific geographic location. In situations where we have high confidence in our technical forensics, we provide our best attribution publicly and report the specific information to the appropriate government authorities. This is especially true when these forensics are compatible with independently gathered information from one of our private or public partners.</li>
# </ul>
# <p><b>Applying the Framework to Our New Discovery</b></p>
# <p>Here is how we use this framework to discuss attribution of the accounts and Pages we removed today:</p>
# <ul>
# <li>As mentioned, we will not provide an assessment of the political motivations of the group behind this activity.</li>
# <li>We have found evidence of connections between these accounts and previously identified IRA accounts. For example, in one instance a known IRA account was an administrator on a Facebook Page controlled by this group. These are important details, but on their own insufficient to support a firm determination, as we have also seen examples of authentic political groups interacting with IRA content in the past.</li>
# <li>Some of the tools, techniques and procedures of this actor are consistent with those we saw from the IRA in 2016 and 2017. But we don’t believe this evidence is strong enough to provide public attribution to the IRA. The TTPs of the IRA have been widely discussed and disseminated, including by Facebook, and it’s possible that a separate actor could be copying their techniques.</li>
# <li>Our technical forensics are insufficient to provide high confidence attribution at this time. We have proactively reported our technical findings to US law enforcement because they have much more information than we do, and may in time be in a position to provide public attribution.</li>
# </ul>
# <p>Given all this, we are not going to attribute this activity to any one group right now. This set of actors has better operational security and does more to conceal their identities than the IRA did around the 2016 election, which is to be expected. We were able to tie previous abuse to the IRA partly because of several unique aspects of their behavior that allowed us to connect a large number of seemingly unrelated accounts. After we named the IRA, we expected the organization to evolve. The set of actors we see now might be the IRA with improved capabilities, or it could be a separate group. This is one of the fundamental limitations of attribution: offensive organizations improve their techniques once they have been uncovered, and it is wishful thinking to believe that we will always be able to identify persistent actors with high confidence.</p>
# <p>The lack of firm attribution in this case or others does not suggest a lack of action. We have invested heavily in people and technology to detect inauthentic attempts to influence political discourse, and enforcing our policies doesn’t require us to confidently attribute the identity of those who violate them or their potential links to foreign actors. We recognize the importance of sharing our best assessment of attribution with the public, and despite the challenges we intend to continue our work to find and stop this behavior, and to publish our results responsibly.</p>
# <p><a href="#top">Back to Top</a><br/>
# <a href="#what-weve-found">What We’ve Found So Far</a><br/>
# <a href="#whos-behind-cyber-threats">How Much Can Companies Know About Who’s Behind Cyber Threats?</a><br/>
# <a href="https://fbnewsroomus.files.wordpress.com/2018/07/sample-content1.zip">Sample Content</a></p>
# </div><!--end:.post-content-->
# </div><!--end:.card-padding-->
# <div class="card-padding remove-padding-top">
# <div class="entry-meta">
# <div class="entry-like">
# <div class="fb-like" data-action="like" data-href="https://newsroom.fb.com/news/2018/07/removing-bad-actors-on-facebook/" data-layout="button_count" data-share="true" data-show-faces="true"></div>
# <a class="button-email" href="mailto:?subject=Facebook%20Newsroom%3A%20Removing%20Bad%20Actors%20on%20Facebook&amp;body=We%20removed%2032%20Pages%20and%20accounts%20from%20Facebook%20and%20Instagram%20because%20they%20were%20involved%20in%20coordinated%20inauthentic%20behavior.%20%20%20%20%20Read%20at%20https%3A%2F%2Fnewsroom.fb.com%2Fnews%2F2018%2F07%2Fremoving-bad-actors-on-facebook%2F">Email</a>
# </div>
# <div class="entry-category">
# <span class="entry-meta-label">Category: </span>
# <a href="https://newsroom.fb.com/news/category/company-news/" title="Company News">Company News</a>
# </div>
# <div class="entry-nav">
# <span class="entry-nav-prev"><a href="https://newsroom.fb.com/news/2018/07/hard-questions-content-reviewers/" rel="prev">Hard Questions: Who Reviews Objectionable Content on Facebook — And Is the Company Doing Enough to Support Them?</a></span>
# <span class="entry-nav-prev no-title"><a href="https://newsroom.fb.com/news/2018/07/hard-questions-content-reviewers/" rel="prev">Previous article</a></span>
# <span class="entry-nav-next"></span>
# <span class="entry-nav-next no-title"></span>
# </div>
# </div><!--end:.entry-meta-->
# </div><!--end:.card-padding-->
# </div><!--end:.card.post.article-single-->
# <div class="related-news">
# <h2>Related News</h2>
# <div class="related-news-item ">
# <p class="date">June 26, 2018</p>
# <h3><a href="https://newsroom.fb.com/news/2018/06/removing-bad-actors-from-facebook/">Removing Bad Actors From Facebook </a></h3>
# </div>
# </div>
# </div>
# </section>
# <!-- Your Google Analytics Plugin is missing the tracking ID -->
# </div><!--end:.wrapper-->
# <div id="newsroom-like">
# <div class="fb-like" data-action="like" data-href="https://newsroom.fb.com/" data-layout="button_count" data-share="true" data-show-faces="false" data-width="330"></div>
# </div>
# <div class="wrapper">
# <footer id="footer-primary">
# <nav class="select-locale">
# <label for="select-locale">Country:</label>
# <select class="select2" id="select-locale">
# <option value="https://newsroom.fb.com/locale/br">Brazil (Português)</option>
# <option value="https://newsroom.fb.com/locale/de">Germany (Deutsch)</option>
# <option value="https://newsroom.fb.com/locale/fr">France (Français)</option>
# <option value="https://newsroom.fb.com/locale/ja">Japan (日本語)</option>
# <option value="https://newsroom.fb.com/locale/ko">Korea (한국어)</option>
# <option value="https://newsroom.fb.com/locale/ltam">Latin America (Español)</option>
# <option value="https://newsroom.fb.com/locale/es">Spain (Español)</option>
# <option selected="selected" value="https://newsroom.fb.com/locale/us">United States (English)</option>
# </select>
# </nav>
# <nav>
# <div class="menu-footer-container"><ul class="menu" id="menu-footer"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1080" id="menu-item-1080"><a href="https://www.facebook.com/facebook/info">About</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1081" id="menu-item-1081"><a href="https://www.facebook.com/help/220217228006012">Contact Us</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1082" id="menu-item-1082"><a href="http://investor.fb.com/">Investor Relations</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1083" id="menu-item-1083"><a href="https://www.facebook.com/about/privacy">Privacy</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1084" id="menu-item-1084"><a href="https://www.facebook.com/legal/terms">Terms</a></li>
# </ul></div> </nav>
# <p>Facebook © 2018</p>
#
# 				Powered by <a class="powered-by-wpcom" href="https://vip.wordpress.com/?utm_source=vip_powered_wpcom&amp;utm_medium=web&amp;utm_campaign=VIP%20Footer%20Credit&amp;utm_term=newsroom.fb.com" rel="generator nofollow">WordPress.com VIP</a> </footer><!--end:.footer-primary-->
# </div><!--end:.wrapper-->
# <!-- wpcom_wp_footer -->
# <div style="display:none">
# </div>
# <div id="carousel-reblog-box">
# <form action="#" name="carousel-reblog">
# <textarea id="carousel-reblog-content" name="carousel-reblog-content" placeholder="Add your thoughts here... (optional)"></textarea>
# <label for="carousel-reblog-to-blog-id" id="carousel-reblog-lblogid">Post to</label>
# <select id="carousel-reblog-to-blog-id" name="carousel-reblog-to-blog-id">
# </select>
# <div class="submit">
# <span class="canceltext"><a class="cancel" href="#">Cancel</a></span>
# <input class="button" id="carousel-reblog-submit" name="carousel-reblog-submit" type="submit" value="Reblog Post"/>
# <input id="carousel-reblog-blog-id" type="hidden" value="62624316"/>
# <input id="carousel-reblog-blog-url" type="hidden" value="https://newsroom.fb.com"/>
# <input id="carousel-reblog-blog-title" type="hidden" value="Facebook Newsroom"/>
# <input id="carousel-reblog-post-url" type="hidden" value=""/>
# <input id="carousel-reblog-post-title" type="hidden" value=""/>
# </div>
# <input id="_wpnonce" name="_wpnonce" type="hidden" value="1c6ad38255"/><input name="_wp_http_referer" type="hidden" value="/news/2018/07/removing-bad-actors-on-facebook/"/> </form>
# <div class="arrow"></div>
# </div>
# <link href="https://s0.wp.com/wp-content/mu-plugins/carousel/jetpack-carousel.css?m=1524699534h&amp;cssminify=yes" id="all-css-0-2" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# <link rel='stylesheet' id='jetpack-carousel-ie8fix-css'  href='https://s1.wp.com/wp-content/mu-plugins/carousel/jetpack-carousel-ie8fix.css?m=1412618825h&#038;ver=20121024' type='text/css' media='all' />
# <![endif]-->
# <script type="text/javascript">
# /* <![CDATA[ */
# var wpcomVipAnalytics = {"is_404":"0","is_home":"0","is_single":"1","is_front_page":"0","is_archive":"0","percentToTrack":"1"};
# /* ]]> */
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var jetpackCarouselStrings = {"widths":[370,700,1000,1200,1400,2000],"is_logged_in":"","lang":"en","ajaxurl":"https:\/\/newsroom.fb.com\/wp-admin\/admin-ajax.php","nonce":"68b90a54b4","display_exif":"1","display_geo":"1","single_image_gallery":"1","single_image_gallery_media_file":"","background_color":"black","comment":"Comment","post_comment":"Post Comment","write_comment":"Write a Comment...","loading_comments":"Loading Comments...","download_original":"View full size <span class=\"photo-size\">{0}<span class=\"photo-size-times\">\u00d7<\/span>{1}<\/span>","no_comment_text":"Please be sure to submit some text with your comment.","no_comment_email":"Please provide an email address to comment.","no_comment_author":"Please provide your name to comment.","comment_post_error":"Sorry, but there was an error posting your comment. Please try again later.","comment_approved":"Your comment was approved.","comment_unapproved":"Your comment is in moderation.","camera":"Camera","aperture":"Aperture","shutter_speed":"Shutter Speed","focal_length":"Focal Length","copyright":"Copyright","comment_registration":"0","require_name_email":"1","login_url":"https:\/\/fbnewsroomus.wordpress.com\/wp-login.php?redirect_to=https%3A%2F%2Fnewsroom.fb.com%2Fnews%2F2018%2F07%2Fremoving-bad-actors-on-facebook%2F","blog_id":"62624316","meta_data":["camera","aperture","shutter_speed","focal_length","copyright"],"local_comments_commenting_as":"<fieldset><label for=\"email\">Email (Required)<\/label> <input type=\"text\" name=\"email\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-email-field\" \/><\/fieldset><fieldset><label for=\"author\">Name (Required)<\/label> <input type=\"text\" name=\"author\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-author-field\" \/><\/fieldset><fieldset><label for=\"url\">Website<\/label> <input type=\"text\" name=\"url\" class=\"jp-carousel-comment-form-field jp-carousel-comment-form-text-field\" id=\"jp-carousel-comment-form-url-field\" \/><\/fieldset>","reblog":"Reblog","reblogged":"Reblogged","reblog_add_thoughts":"Add your thoughts here... (optional)","reblogging":"Reblogging...","post_reblog":"Post Reblog","stats_query_args":"blog=62624316&v=wpcom&tz=-7&user_id=0&subd=fbnewsroomus","is_public":"1","reblog_enabled":""};
# /* ]]> */
# </script>
# <script src="https://s0.wp.com/_static/??-" type="text/javascript"></script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script><script async="" defer="" src="//stats.wp.com/w.js?56" type="text/javascript"></script>
# <script type="text/javascript">
# _tkq = window._tkq || [];
# _stq = window._stq || [];
# _tkq.push(['storeContext', {'blog_id':'62624316','blog_tz':'-7','user_lang':'en','blog_lang':'en','user_id':'0'}]);
# _stq.push(['view', {'blog':'62624316','v':'wpcom','tz':'-7','user_id':'0','post':'11935','subd':'fbnewsroomus'}]);
# function st_vt() {var x=document.createElement("img");x.src="https://pixel.wp.com/g.gif?blog=62624316&v=wpcomvt&tz=-7&user_id=0&post=11935&subd=fbnewsroomus&rand="+Math.random();}
# _stq.push(['extra', {'crypt':''}]);
# _stq.push([ 'clickTrackerInit', '62624316', '11935' ]);
# 	</script>
# <noscript><img alt="" src="https://pixel.wp.com/b.gif?v=noscript" style="height:0px;width:0px;overflow:hidden"/></noscript>
# <script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script>
# </body>
# </html>
# <!--
# 	generated 61 seconds ago
# 	generated in 0.158 seconds
# 	served from batcache in 0.001 seconds
# 	expires in 239 seconds
# -->

# %%
text = soup.find("div", {"class": "post-content"}).text

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %%
sents = sent_tokenize(text)
sents
# Out:
# ['\nToday we removed 32 Pages and accounts from Facebook and Instagram because they were involved in coordinated inauthentic behavior.',
#  'This kind of behavior is not allowed on Facebook because we don’t want people or organizations creating networks of accounts to mislead others about who they are, or what they’re doing.',
#  'We’re still in the very early stages of our investigation and don’t have all the facts — including who may be behind this.',
#  'But we are sharing what we know today given the connection between these bad actors and protests that are planned in Washington next week.',
#  'We will update this post with more details when we have them, or if the facts we have change.',
#  'It’s clear that whoever set up these accounts went to much greater lengths to obscure their true identities than the Russian-based Internet Research Agency (IRA) has in the past.',
#  'We believe this could be partly due to changes we’ve made over the last year to make this kind of abuse much harder.',
#  'But security is not something that’s ever done.',
#  'We face determined, well-funded adversaries who will never give up and are constantly changing tactics.',
#  'It’s an arms race and we need to constantly improve too.',
#  'It’s why we’re investing heavily in more people and better technology to prevent bad actors misusing Facebook — as well as working much more closely with law enforcement and other tech companies to better understand the threats we face.',
#  'What We’ve Found So Far\nHow Much Can Companies Know About Who’s Behind Cyber Threats?',
#  'Sample Content\n\xa0\nJuly 31, 2018\nWhat We’ve Found So Far\nBy Nathaniel Gleicher, Head of Cybersecurity Policy\nAbout two weeks ago we identified the first of eight Pages and 17 profiles on Facebook, as well as seven Instagram accounts, that violate our ban on coordinated inauthentic behavior.',
#  'We removed all of them this morning once we’d completed our initial investigation and shared the information with US law enforcement agencies, Congress, other technology companies, and the\xa0Atlantic Council’s Digital Forensic Research Lab, a research organization that helps us identify and analyze abuse on Facebook.',
#  'In total, more than 290,000 accounts followed at least one of these Pages, the earliest of which was created in March 2017.',
#  'The latest was created in May 2018.',
#  'The most followed Facebook Pages were “Aztlan Warriors,” “Black Elevation,” “Mindful Being,” and “Resisters.” The remaining Pages had between zero and 10 followers, and the Instagram accounts had zero followers.',
#  'There were more than 9,500 organic posts created by these accounts on Facebook, and one piece of content on Instagram.',
#  'They ran about 150 ads for approximately $11,000 on Facebook and Instagram, paid for in US and Canadian dollars.',
#  'The first ad was created in April 2017, and the last was created in June 2018.',
#  'The Pages created about 30 events since May 2017.',
#  'About half had fewer than 100 accounts interested in attending.',
#  'The largest had approximately 4,700 accounts interested in attending, and 1,400 users said that they would attend.',
#  'We are still reviewing all of the content and ads from these Pages.',
#  'In the meantime here are some examples of the content and ads posted by these Pages.',
#  'These bad actors have been more careful to cover their tracks, in part due to the actions we’ve taken to prevent abuse over the past year.',
#  'For example they used VPNs and internet phone services, and paid third parties to run ads on their behalf.',
#  'As we’ve told law enforcement and Congress,\xa0we still don’t have firm evidence to say with certainty who’s behind this effort.',
#  'Some of the activity is consistent with what we saw from the IRA before and after the 2016 elections.',
#  'And we’ve found evidence of some connections between these accounts and IRA accounts we disabled last year, which is covered below.',
#  'But there are differences, too.',
#  'For example, while IP addresses are easy to spoof, the IRA accounts we disabled last year sometimes used Russian IP addresses.',
#  'We haven’t seen those here.',
#  'We found this activity as part of our ongoing efforts to identify coordinated inauthentic behavior.',
#  'Given these bad actors are now working harder to obscure their identities, we need to find every small mistake they make.',
#  'It’s why we’re following up on thousands of leads, including information from law enforcement and lessons we learned from last year’s IRA investigation.',
#  'The IRA engaged with many legitimate Pages, so these leads sometimes turn up nothing.',
#  'However, one of these leads did turn up something.',
#  'One of the IRA accounts we disabled in 2017 shared a Facebook Event hosted by the “Resisters” Page.',
#  'This Page also previously had an IRA account as one of its admins for only seven minutes.',
#  'These discoveries helped us uncover the other inauthentic accounts we disabled today.',
#  'The “Resisters” Page also created a Facebook Event for a protest on August 10 to 12 and enlisted support from real people.',
#  'The Event – “No Unite the Right 2 – DC” – was scheduled to protest an August “Unite the Right” event in Washington.',
#  'Inauthentic admins of the “Resisters” Page connected with admins from five legitimate Pages to co-host the event.',
#  'These legitimate Pages unwittingly helped build interest in “No Unite Right 2 – DC” and posted information about transportation, materials, and locations so people could get to the protests.',
#  'We disabled the event earlier today and have reached out to the admins of the five other Pages to update them on what happened.',
#  'This afternoon, we’ll begin informing the approximately 2,600 users interested in the event, and the more than 600 users who said they’d attend, about what happened.',
#  'We don’t have all the facts, but we’ll work closely with others as we continue our investigation.',
#  'We hope to get new information from law enforcement and other companies so we can better understand what happened — and we’ll share any additional findings with law enforcement and Congress.',
#  'However, we may never be able to identify the source with the same level of confidence we had in naming the IRA last year.',
#  'See Alex Stamos’ post below on why attribution can be really hard.',
#  'We’re seeing real benefits from working with outside experts.',
#  'Partners like the Atlantic Council have provided invaluable help in identifying bad actors and analyzing their behavior across the internet.',
#  'Based on leads from the recent US Department of Justice indictment, the Atlantic Council identified a Facebook group with roughly 4,000 members.',
#  'It was created by Russian government actors but had been dormant since we disabled the group’s admins last year.',
#  'Groups typically persist on Facebook even when their admins are disabled, but we chose to remove this group to protect the privacy of its members in advance of a report that the Atlantic Council\xa0plans to publish as soon\xa0as it concludes its analysis.',
#  'It will follow this report in the coming weeks with an analysis of the Pages, accounts and profiles we disabled today.',
#  'July 31, 2018\nHow Much Can Companies Know About Who’s Behind Cyber Threats?',
#  'By Alex Stamos, Chief Security Officer\nDeciding when and how to publicly link suspicious activity to a specific organization, government, or individual is a challenge that governments and many companies face.',
#  'Last year, we said the Russia-based Internet Research Agency (IRA) was behind much of the abuse we found around the 2016 election.',
#  'But today we’re shutting down 32 Pages and accounts engaged in coordinated inauthentic behavior without saying that a specific group or country is responsible.',
#  'The process of attributing observed activity to particular threat actors has been much debated by academics\xa0and within the intelligence community.',
#  'All modern intelligence agencies use their own internal guidelines to help them consistently communicate their findings to policymakers and the public.',
#  'Companies, by comparison, operate with relatively limited information from outside sources — though as we get more involved in detecting and investigating this kind of misuse, we also need clear and consistent ways to confront and communicate these issues head on.',
#  'Determining Who is Behind an Action\nThe first challenge is figuring out the type of entity to which we are attributing responsibility.',
#  'This is harder than it might sound.',
#  'It is standard for both traditional security attacks and information operations to be conducted using commercial infrastructure or computers belonging to innocent people that have been compromised.',
#  'As a result, simple techniques like blaming the owner of an IP address that was used to register a malicious account usually aren’t sufficient to accurately determine who’s responsible.',
#  'Instead, we try to:\n\nLink suspicious activity to the individual or group with primary operational responsibility for the malicious action.',
#  'We can then potentially associate multiple campaigns to one set of actors, study how they abuse our systems, and take appropriate countermeasures.',
#  'Tie a specific actor to a real-world sponsor.',
#  'This could include a political organization, a nation-state, or a non-political entity.',
#  'The relationship between malicious actors and real-world sponsors can be difficult to determine in practice, especially for activity sponsored by nation-states.',
#  'In his seminal paper on the topic, Jason Healey described a spectrum to measure the degree of state responsibility for cyber attacks.',
#  'This included 10 discrete steps ranging from “state-prohibited,” where a state actively stops attacks originating from their territory, to “state-integrated,” where the attackers serve as fully integrated resources of the national government.',
#  'This framework is helpful when looking at the two major organized attempts to interfere in the 2016 US election on Facebook that we have found to date.',
#  'One set of actors used hacking techniques to steal information from email accounts — and then contacted journalists using social media to encourage them to publish stories about the stolen data.',
#  'Based on our investigation and information provided by the US government, we concluded that this work was the responsibility of groups tied to the GRU, or Russian military intelligence.',
#  'The recent Special Counsel indictment of GRU officers supports our assessment in this case, and we would consider these actions to be “state-integrated” on Healey’s spectrum.',
#  'The other major organized effort did not include traditional cyber attacks but was instead designed to sow division using social media.',
#  'Based on our own investigations, we assessed with high confidence that this group was part of the IRA.',
#  'There has been a public debate about the relationship between the IRA and the Russian government — though most seem to conclude this activity is between “state-encouraged” and “state-ordered” using Healey’s definitions.',
#  'Four Methods of Attribution\nAcademics have written about a variety of methods for attributing activity to cyber actors, but for our purposes we simplify these methods into an attribution model with four general categories.',
#  'And while all of these are appropriate for government organizations, we do not believe some of them should be used by companies:\n\nPolitical Motivations: In this model, inferred political motivations are measured against the known political goals of a nation-state.',
#  'Providing public attribution based on political evidence is especially challenging for companies because we don’t have the information needed to make this kind of evaluation.',
#  'For example, we lack the analytical capabilities, signals intelligence, and human sources available to the intelligence community.',
#  'As a result, we don’t believe it is appropriate for Facebook to give public comment on the political motivations of nation-states.',
#  'Coordination: Sometimes we will observe signs of coordination between threat actors even when the evidence indicates that they are operating separate technical infrastructure.',
#  'We have to be careful, though, because coincidences can happen.',
#  'Collaboration that requires sharing of secrets, such as the possession of stolen data before it has been publicly disclosed, should be treated as much stronger evidence than open interactions in public forums.',
#  'Tools, Techniques and Procedures (TTPs): By looking at how a threat group performs their actions to achieve a goal — including reconnaissance, planning, exploitation, command and control, and exfiltration or distribution of information — it is often possible to infer a linkage between a specific incident and a known threat actor.',
#  'We believe there is value in providing our assessment of how TTPs compare with previous events, but we don’t plan to rely solely upon TTPs to provide any direct attribution.',
#  'Technical Forensics: By studying the specific indicators of compromise (IOCs) left behind in an incident, it’s sometimes possible to trace activity back to a known or new organized actor.',
#  'Sometimes these IOCs point to a specific group using shared software or infrastructure, or to a specific geographic location.',
#  'In situations where we have high confidence in our technical forensics, we provide our best attribution publicly and report the specific information to the appropriate government authorities.',
#  'This is especially true when these forensics are compatible with independently gathered information from one of our private or public partners.',
#  'Applying the Framework to Our New Discovery\nHere is how we use this framework to discuss attribution of the accounts and Pages we removed today:\n\nAs mentioned, we will not provide an assessment of the political motivations of the group behind this activity.',
#  'We have found evidence of connections between these accounts and previously identified IRA accounts.',
#  'For example, in one instance a known IRA account was an administrator on a Facebook Page controlled by this group.',
#  'These are important details, but on their own insufficient to support a firm determination, as we have also seen examples of authentic political groups interacting with IRA content in the past.',
#  'Some of the tools, techniques and procedures of this actor are consistent with those we saw from the IRA in 2016 and 2017.',
#  'But we don’t believe this evidence is strong enough to provide public attribution to the IRA.',
#  'The TTPs of the IRA have been widely discussed and disseminated, including by Facebook, and it’s possible that a separate actor could be copying their techniques.',
#  'Our technical forensics are insufficient to provide high confidence attribution at this time.',
#  'We have proactively reported our technical findings to US law enforcement because they have much more information than we do, and may in time be in a position to provide public attribution.',
#  'Given all this, we are not going to attribute this activity to any one group right now.',
#  'This set of actors has better operational security and does more to conceal their identities than the IRA did around the 2016 election, which is to be expected.',
#  'We were able to tie previous abuse to the IRA partly because of several unique aspects of their behavior that allowed us to connect a large number of seemingly unrelated accounts.',
#  'After we named the IRA, we expected the organization to evolve.',
#  'The set of actors we see now might be the IRA with improved capabilities, or it could be a separate group.',
#  'This is one of the fundamental limitations of attribution: offensive organizations improve their techniques once they have been uncovered, and it is wishful thinking to believe that we will always be able to identify persistent actors with high confidence.',
#  'The lack of firm attribution in this case or others does not suggest a lack of action.',
#  'We have invested heavily in people and technology to detect inauthentic attempts to influence political discourse, and enforcing our policies doesn’t require us to confidently attribute the identity of those who violate them or their potential links to foreign actors.',
#  'We recognize the importance of sharing our best assessment of attribution with the public, and despite the challenges we intend to continue our work to find and stop this behavior, and to publish our results responsibly.',
#  'Back to Top\nWhat We’ve Found So Far\nHow Much Can Companies Know About Who’s Behind Cyber Threats?',
#  'Sample Content']

# %%
word_sent = word_tokenize(text.lower())
word_sent
# Out:
# ['today',
#  'we',
#  'removed',
#  '32',
#  'pages',
#  'and',
#  'accounts',
#  'from',
#  'facebook',
#  'and',
#  'instagram',
#  'because',
#  'they',
#  'were',
#  'involved',
#  'in',
#  'coordinated',
#  'inauthentic',
#  'behavior',
#  '.',
#  'this',
#  'kind',
#  'of',
#  'behavior',
#  'is',
#  'not',
#  'allowed',
#  'on',
#  'facebook',
#  'because',
#  'we',
#  'don',
#  '’',
#  't',
#  'want',
#  'people',
#  'or',
#  'organizations',
#  'creating',
#  'networks',
#  'of',
#  'accounts',
#  'to',
#  'mislead',
#  'others',
#  'about',
#  'who',
#  'they',
#  'are',
#  ',',
#  'or',
#  'what',
#  'they',
#  '’',
#  're',
#  'doing',
#  '.',
#  'we',
#  '’',
#  're',
#  'still',
#  'in',
#  'the',
#  'very',
#  'early',
#  'stages',
#  'of',
#  'our',
#  'investigation',
#  'and',
#  'don',
#  '’',
#  't',
#  'have',
#  'all',
#  'the',
#  'facts',
#  '—',
#  'including',
#  'who',
#  'may',
#  'be',
#  'behind',
#  'this',
#  '.',
#  'but',
#  'we',
#  'are',
#  'sharing',
#  'what',
#  'we',
#  'know',
#  'today',
#  'given',
#  'the',
#  'connection',
#  'between',
#  'these',
#  'bad',
#  'actors',
#  'and',
#  'protests',
#  'that',
#  'are',
#  'planned',
#  'in',
#  'washington',
#  'next',
#  'week',
#  '.',
#  'we',
#  'will',
#  'update',
#  'this',
#  'post',
#  'with',
#  'more',
#  'details',
#  'when',
#  'we',
#  'have',
#  'them',
#  ',',
#  'or',
#  'if',
#  'the',
#  'facts',
#  'we',
#  'have',
#  'change',
#  '.',
#  'it',
#  '’',
#  's',
#  'clear',
#  'that',
#  'whoever',
#  'set',
#  'up',
#  'these',
#  'accounts',
#  'went',
#  'to',
#  'much',
#  'greater',
#  'lengths',
#  'to',
#  'obscure',
#  'their',
#  'true',
#  'identities',
#  'than',
#  'the',
#  'russian-based',
#  'internet',
#  'research',
#  'agency',
#  '(',
#  'ira',
#  ')',
#  'has',
#  'in',
#  'the',
#  'past',
#  '.',
#  'we',
#  'believe',
#  'this',
#  'could',
#  'be',
#  'partly',
#  'due',
#  'to',
#  'changes',
#  'we',
#  '’',
#  've',
#  'made',
#  'over',
#  'the',
#  'last',
#  'year',
#  'to',
#  'make',
#  'this',
#  'kind',
#  'of',
#  'abuse',
#  'much',
#  'harder',
#  '.',
#  'but',
#  'security',
#  'is',
#  'not',
#  'something',
#  'that',
#  '’',
#  's',
#  'ever',
#  'done',
#  '.',
#  'we',
#  'face',
#  'determined',
#  ',',
#  'well-funded',
#  'adversaries',
#  'who',
#  'will',
#  'never',
#  'give',
#  'up',
#  'and',
#  'are',
#  'constantly',
#  'changing',
#  'tactics',
#  '.',
#  'it',
#  '’',
#  's',
#  'an',
#  'arms',
#  'race',
#  'and',
#  'we',
#  'need',
#  'to',
#  'constantly',
#  'improve',
#  'too',
#  '.',
#  'it',
#  '’',
#  's',
#  'why',
#  'we',
#  '’',
#  're',
#  'investing',
#  'heavily',
#  'in',
#  'more',
#  'people',
#  'and',
#  'better',
#  'technology',
#  'to',
#  'prevent',
#  'bad',
#  'actors',
#  'misusing',
#  'facebook',
#  '—',
#  'as',
#  'well',
#  'as',
#  'working',
#  'much',
#  'more',
#  'closely',
#  'with',
#  'law',
#  'enforcement',
#  'and',
#  'other',
#  'tech',
#  'companies',
#  'to',
#  'better',
#  'understand',
#  'the',
#  'threats',
#  'we',
#  'face',
#  '.',
#  'what',
#  'we',
#  '’',
#  've',
#  'found',
#  'so',
#  'far',
#  'how',
#  'much',
#  'can',
#  'companies',
#  'know',
#  'about',
#  'who',
#  '’',
#  's',
#  'behind',
#  'cyber',
#  'threats',
#  '?',
#  'sample',
#  'content',
#  'july',
#  '31',
#  ',',
#  '2018',
#  'what',
#  'we',
#  '’',
#  've',
#  'found',
#  'so',
#  'far',
#  'by',
#  'nathaniel',
#  'gleicher',
#  ',',
#  'head',
#  'of',
#  'cybersecurity',
#  'policy',
#  'about',
#  'two',
#  'weeks',
#  'ago',
#  'we',
#  'identified',
#  'the',
#  'first',
#  'of',
#  'eight',
#  'pages',
#  'and',
#  '17',
#  'profiles',
#  'on',
#  'facebook',
#  ',',
#  'as',
#  'well',
#  'as',
#  'seven',
#  'instagram',
#  'accounts',
#  ',',
#  'that',
#  'violate',
#  'our',
#  'ban',
#  'on',
#  'coordinated',
#  'inauthentic',
#  'behavior',
#  '.',
#  'we',
#  'removed',
#  'all',
#  'of',
#  'them',
#  'this',
#  'morning',
#  'once',
#  'we',
#  '’',
#  'd',
#  'completed',
#  'our',
#  'initial',
#  'investigation',
#  'and',
#  'shared',
#  'the',
#  'information',
#  'with',
#  'us',
#  'law',
#  'enforcement',
#  'agencies',
#  ',',
#  'congress',
#  ',',
#  'other',
#  'technology',
#  'companies',
#  ',',
#  'and',
#  'the',
#  'atlantic',
#  'council',
#  '’',
#  's',
#  'digital',
#  'forensic',
#  'research',
#  'lab',
#  ',',
#  'a',
#  'research',
#  'organization',
#  'that',
#  'helps',
#  'us',
#  'identify',
#  'and',
#  'analyze',
#  'abuse',
#  'on',
#  'facebook',
#  '.',
#  'in',
#  'total',
#  ',',
#  'more',
#  'than',
#  '290,000',
#  'accounts',
#  'followed',
#  'at',
#  'least',
#  'one',
#  'of',
#  'these',
#  'pages',
#  ',',
#  'the',
#  'earliest',
#  'of',
#  'which',
#  'was',
#  'created',
#  'in',
#  'march',
#  '2017.',
#  'the',
#  'latest',
#  'was',
#  'created',
#  'in',
#  'may',
#  '2018.',
#  'the',
#  'most',
#  'followed',
#  'facebook',
#  'pages',
#  'were',
#  '“',
#  'aztlan',
#  'warriors',
#  ',',
#  '”',
#  '“',
#  'black',
#  'elevation',
#  ',',
#  '”',
#  '“',
#  'mindful',
#  'being',
#  ',',
#  '”',
#  'and',
#  '“',
#  'resisters.',
#  '”',
#  'the',
#  'remaining',
#  'pages',
#  'had',
#  'between',
#  'zero',
#  'and',
#  '10',
#  'followers',
#  ',',
#  'and',
#  'the',
#  'instagram',
#  'accounts',
#  'had',
#  'zero',
#  'followers',
#  '.',
#  'there',
#  'were',
#  'more',
#  'than',
#  '9,500',
#  'organic',
#  'posts',
#  'created',
#  'by',
#  'these',
#  'accounts',
#  'on',
#  'facebook',
#  ',',
#  'and',
#  'one',
#  'piece',
#  'of',
#  'content',
#  'on',
#  'instagram',
#  '.',
#  'they',
#  'ran',
#  'about',
#  '150',
#  'ads',
#  'for',
#  'approximately',
#  '$',
#  '11,000',
#  'on',
#  'facebook',
#  'and',
#  'instagram',
#  ',',
#  'paid',
#  'for',
#  'in',
#  'us',
#  'and',
#  'canadian',
#  'dollars',
#  '.',
#  'the',
#  'first',
#  'ad',
#  'was',
#  'created',
#  'in',
#  'april',
#  '2017',
#  ',',
#  'and',
#  'the',
#  'last',
#  'was',
#  'created',
#  'in',
#  'june',
#  '2018.',
#  'the',
#  'pages',
#  'created',
#  'about',
#  '30',
#  'events',
#  'since',
#  'may',
#  '2017.',
#  'about',
#  'half',
#  'had',
#  'fewer',
#  'than',
#  '100',
#  'accounts',
#  'interested',
#  'in',
#  'attending',
#  '.',
#  'the',
#  'largest',
#  'had',
#  'approximately',
#  '4,700',
#  'accounts',
#  'interested',
#  'in',
#  'attending',
#  ',',
#  'and',
#  '1,400',
#  'users',
#  'said',
#  'that',
#  'they',
#  'would',
#  'attend',
#  '.',
#  'we',
#  'are',
#  'still',
#  'reviewing',
#  'all',
#  'of',
#  'the',
#  'content',
#  'and',
#  'ads',
#  'from',
#  'these',
#  'pages',
#  '.',
#  'in',
#  'the',
#  'meantime',
#  'here',
#  'are',
#  'some',
#  'examples',
#  'of',
#  'the',
#  'content',
#  'and',
#  'ads',
#  'posted',
#  'by',
#  'these',
#  'pages',
#  '.',
#  'these',
#  'bad',
#  'actors',
#  'have',
#  'been',
#  'more',
#  'careful',
#  'to',
#  'cover',
#  'their',
#  'tracks',
#  ',',
#  'in',
#  'part',
#  'due',
#  'to',
#  'the',
#  'actions',
#  'we',
#  '’',
#  've',
#  'taken',
#  'to',
#  'prevent',
#  'abuse',
#  'over',
#  'the',
#  'past',
#  'year',
#  '.',
#  'for',
#  'example',
#  'they',
#  'used',
#  'vpns',
#  'and',
#  'internet',
#  'phone',
#  'services',
#  ',',
#  'and',
#  'paid',
#  'third',
#  'parties',
#  'to',
#  'run',
#  'ads',
#  'on',
#  'their',
#  'behalf',
#  '.',
#  'as',
#  'we',
#  '’',
#  've',
#  'told',
#  'law',
#  'enforcement',
#  'and',
#  'congress',
#  ',',
#  'we',
#  'still',
#  'don',
#  '’',
#  't',
#  'have',
#  'firm',
#  'evidence',
#  'to',
#  'say',
#  'with',
#  'certainty',
#  'who',
#  '’',
#  's',
#  'behind',
#  'this',
#  'effort',
#  '.',
#  'some',
#  'of',
#  'the',
#  'activity',
#  'is',
#  'consistent',
#  'with',
#  'what',
#  'we',
#  'saw',
#  'from',
#  'the',
#  'ira',
#  'before',
#  'and',
#  'after',
#  'the',
#  '2016',
#  'elections',
#  '.',
#  'and',
#  'we',
#  '’',
#  've',
#  'found',
#  'evidence',
#  'of',
#  'some',
#  'connections',
#  'between',
#  'these',
#  'accounts',
#  'and',
#  'ira',
#  'accounts',
#  'we',
#  'disabled',
#  'last',
#  'year',
#  ',',
#  'which',
#  'is',
#  'covered',
#  'below',
#  '.',
#  'but',
#  'there',
#  'are',
#  'differences',
#  ',',
#  'too',
#  '.',
#  'for',
#  'example',
#  ',',
#  'while',
#  'ip',
#  'addresses',
#  'are',
#  'easy',
#  'to',
#  'spoof',
#  ',',
#  'the',
#  'ira',
#  'accounts',
#  'we',
#  'disabled',
#  'last',
#  'year',
#  'sometimes',
#  'used',
#  'russian',
#  'ip',
#  'addresses',
#  '.',
#  'we',
#  'haven',
#  '’',
#  't',
#  'seen',
#  'those',
#  'here',
#  '.',
#  'we',
#  'found',
#  'this',
#  'activity',
#  'as',
#  'part',
#  'of',
#  'our',
#  'ongoing',
#  'efforts',
#  'to',
#  'identify',
#  'coordinated',
#  'inauthentic',
#  'behavior',
#  '.',
#  'given',
#  'these',
#  'bad',
#  'actors',
#  'are',
#  'now',
#  'working',
#  'harder',
#  'to',
#  'obscure',
#  'their',
#  'identities',
#  ',',
#  'we',
#  'need',
#  'to',
#  'find',
#  'every',
#  'small',
#  'mistake',
#  'they',
#  'make',
#  '.',
#  'it',
#  '’',
#  's',
#  'why',
#  'we',
#  '’',
#  're',
#  'following',
#  'up',
#  'on',
#  'thousands',
#  'of',
#  'leads',
#  ',',
#  'including',
#  'information',
#  'from',
#  'law',
#  'enforcement',
#  'and',
#  'lessons',
#  'we',
#  'learned',
#  'from',
#  'last',
#  'year',
#  '’',
#  's',
#  'ira',
#  'investigation',
#  '.',
#  'the',
#  'ira',
#  'engaged',
#  'with',
#  'many',
#  'legitimate',
#  'pages',
#  ',',
#  'so',
#  'these',
#  'leads',
#  'sometimes',
#  'turn',
#  'up',
#  'nothing',
#  '.',
#  'however',
#  ',',
#  'one',
#  'of',
#  'these',
#  'leads',
#  'did',
#  'turn',
#  'up',
#  'something',
#  '.',
#  'one',
#  'of',
#  'the',
#  'ira',
#  'accounts',
#  'we',
#  'disabled',
#  'in',
#  '2017',
#  'shared',
#  'a',
#  'facebook',
#  'event',
#  'hosted',
#  'by',
#  'the',
#  '“',
#  'resisters',
#  '”',
#  'page',
#  '.',
#  'this',
#  'page',
#  'also',
#  'previously',
#  'had',
#  'an',
#  'ira',
#  'account',
#  'as',
#  'one',
#  'of',
#  'its',
#  'admins',
#  'for',
#  'only',
#  'seven',
#  'minutes',
#  '.',
#  'these',
#  'discoveries',
#  'helped',
#  'us',
#  'uncover',
#  'the',
#  'other',
#  'inauthentic',
#  'accounts',
#  'we',
#  'disabled',
#  'today',
#  '.',
#  'the',
#  '“',
#  'resisters',
#  '”',
#  'page',
#  'also',
#  'created',
#  'a',
#  'facebook',
#  'event',
#  'for',
#  'a',
#  'protest',
#  'on',
#  'august',
#  '10',
#  'to',
#  '12',
#  'and',
#  'enlisted',
#  'support',
#  'from',
#  'real',
#  'people',
#  '.',
#  'the',
#  'event',
#  '–',
#  '“',
#  'no',
#  'unite',
#  'the',
#  'right',
#  '2',
#  '–',
#  'dc',
#  '”',
#  '–',
#  'was',
#  'scheduled',
#  'to',
#  'protest',
#  'an',
#  'august',
#  '“',
#  'unite',
#  'the',
#  'right',
#  '”',
#  'event',
#  'in',
#  'washington',
#  '.',
#  'inauthentic',
#  'admins',
#  'of',
#  'the',
#  '“',
#  'resisters',
#  '”',
#  'page',
#  'connected',
#  'with',
#  'admins',
#  'from',
#  'five',
#  'legitimate',
#  'pages',
#  'to',
#  'co-host',
#  'the',
#  'event',
#  '.',
#  'these',
#  'legitimate',
#  'pages',
#  ...]

# %%
mylist = ['’', '“', '”']
_stopwords = set(stopwords.words('english') + list(punctuation) + mylist)
_stopwords
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '{',
#  '|',
#  '}',
#  '~',
#  '’',
#  '“',
#  '”'}

# %%
word_sent=[word for word in word_sent if word not in _stopwords]

# %%
word_sent
# Out:
# ['today',
#  'removed',
#  '32',
#  'pages',
#  'accounts',
#  'facebook',
#  'instagram',
#  'involved',
#  'coordinated',
#  'inauthentic',
#  'behavior',
#  'kind',
#  'behavior',
#  'allowed',
#  'facebook',
#  'want',
#  'people',
#  'organizations',
#  'creating',
#  'networks',
#  'accounts',
#  'mislead',
#  'others',
#  'still',
#  'early',
#  'stages',
#  'investigation',
#  'facts',
#  '—',
#  'including',
#  'may',
#  'behind',
#  'sharing',
#  'know',
#  'today',
#  'given',
#  'connection',
#  'bad',
#  'actors',
#  'protests',
#  'planned',
#  'washington',
#  'next',
#  'week',
#  'update',
#  'post',
#  'details',
#  'facts',
#  'change',
#  'clear',
#  'whoever',
#  'set',
#  'accounts',
#  'went',
#  'much',
#  'greater',
#  'lengths',
#  'obscure',
#  'true',
#  'identities',
#  'russian-based',
#  'internet',
#  'research',
#  'agency',
#  'ira',
#  'past',
#  'believe',
#  'could',
#  'partly',
#  'due',
#  'changes',
#  'made',
#  'last',
#  'year',
#  'make',
#  'kind',
#  'abuse',
#  'much',
#  'harder',
#  'security',
#  'something',
#  'ever',
#  'done',
#  'face',
#  'determined',
#  'well-funded',
#  'adversaries',
#  'never',
#  'give',
#  'constantly',
#  'changing',
#  'tactics',
#  'arms',
#  'race',
#  'need',
#  'constantly',
#  'improve',
#  'investing',
#  'heavily',
#  'people',
#  'better',
#  'technology',
#  'prevent',
#  'bad',
#  'actors',
#  'misusing',
#  'facebook',
#  '—',
#  'well',
#  'working',
#  'much',
#  'closely',
#  'law',
#  'enforcement',
#  'tech',
#  'companies',
#  'better',
#  'understand',
#  'threats',
#  'face',
#  'found',
#  'far',
#  'much',
#  'companies',
#  'know',
#  'behind',
#  'cyber',
#  'threats',
#  'sample',
#  'content',
#  'july',
#  '31',
#  '2018',
#  'found',
#  'far',
#  'nathaniel',
#  'gleicher',
#  'head',
#  'cybersecurity',
#  'policy',
#  'two',
#  'weeks',
#  'ago',
#  'identified',
#  'first',
#  'eight',
#  'pages',
#  '17',
#  'profiles',
#  'facebook',
#  'well',
#  'seven',
#  'instagram',
#  'accounts',
#  'violate',
#  'ban',
#  'coordinated',
#  'inauthentic',
#  'behavior',
#  'removed',
#  'morning',
#  'completed',
#  'initial',
#  'investigation',
#  'shared',
#  'information',
#  'us',
#  'law',
#  'enforcement',
#  'agencies',
#  'congress',
#  'technology',
#  'companies',
#  'atlantic',
#  'council',
#  'digital',
#  'forensic',
#  'research',
#  'lab',
#  'research',
#  'organization',
#  'helps',
#  'us',
#  'identify',
#  'analyze',
#  'abuse',
#  'facebook',
#  'total',
#  '290,000',
#  'accounts',
#  'followed',
#  'least',
#  'one',
#  'pages',
#  'earliest',
#  'created',
#  'march',
#  '2017.',
#  'latest',
#  'created',
#  'may',
#  '2018.',
#  'followed',
#  'facebook',
#  'pages',
#  'aztlan',
#  'warriors',
#  'black',
#  'elevation',
#  'mindful',
#  'resisters.',
#  'remaining',
#  'pages',
#  'zero',
#  '10',
#  'followers',
#  'instagram',
#  'accounts',
#  'zero',
#  'followers',
#  '9,500',
#  'organic',
#  'posts',
#  'created',
#  'accounts',
#  'facebook',
#  'one',
#  'piece',
#  'content',
#  'instagram',
#  'ran',
#  '150',
#  'ads',
#  'approximately',
#  '11,000',
#  'facebook',
#  'instagram',
#  'paid',
#  'us',
#  'canadian',
#  'dollars',
#  'first',
#  'ad',
#  'created',
#  'april',
#  '2017',
#  'last',
#  'created',
#  'june',
#  '2018.',
#  'pages',
#  'created',
#  '30',
#  'events',
#  'since',
#  'may',
#  '2017.',
#  'half',
#  'fewer',
#  '100',
#  'accounts',
#  'interested',
#  'attending',
#  'largest',
#  'approximately',
#  '4,700',
#  'accounts',
#  'interested',
#  'attending',
#  '1,400',
#  'users',
#  'said',
#  'would',
#  'attend',
#  'still',
#  'reviewing',
#  'content',
#  'ads',
#  'pages',
#  'meantime',
#  'examples',
#  'content',
#  'ads',
#  'posted',
#  'pages',
#  'bad',
#  'actors',
#  'careful',
#  'cover',
#  'tracks',
#  'part',
#  'due',
#  'actions',
#  'taken',
#  'prevent',
#  'abuse',
#  'past',
#  'year',
#  'example',
#  'used',
#  'vpns',
#  'internet',
#  'phone',
#  'services',
#  'paid',
#  'third',
#  'parties',
#  'run',
#  'ads',
#  'behalf',
#  'told',
#  'law',
#  'enforcement',
#  'congress',
#  'still',
#  'firm',
#  'evidence',
#  'say',
#  'certainty',
#  'behind',
#  'effort',
#  'activity',
#  'consistent',
#  'saw',
#  'ira',
#  '2016',
#  'elections',
#  'found',
#  'evidence',
#  'connections',
#  'accounts',
#  'ira',
#  'accounts',
#  'disabled',
#  'last',
#  'year',
#  'covered',
#  'differences',
#  'example',
#  'ip',
#  'addresses',
#  'easy',
#  'spoof',
#  'ira',
#  'accounts',
#  'disabled',
#  'last',
#  'year',
#  'sometimes',
#  'used',
#  'russian',
#  'ip',
#  'addresses',
#  'seen',
#  'found',
#  'activity',
#  'part',
#  'ongoing',
#  'efforts',
#  'identify',
#  'coordinated',
#  'inauthentic',
#  'behavior',
#  'given',
#  'bad',
#  'actors',
#  'working',
#  'harder',
#  'obscure',
#  'identities',
#  'need',
#  'find',
#  'every',
#  'small',
#  'mistake',
#  'make',
#  'following',
#  'thousands',
#  'leads',
#  'including',
#  'information',
#  'law',
#  'enforcement',
#  'lessons',
#  'learned',
#  'last',
#  'year',
#  'ira',
#  'investigation',
#  'ira',
#  'engaged',
#  'many',
#  'legitimate',
#  'pages',
#  'leads',
#  'sometimes',
#  'turn',
#  'nothing',
#  'however',
#  'one',
#  'leads',
#  'turn',
#  'something',
#  'one',
#  'ira',
#  'accounts',
#  'disabled',
#  '2017',
#  'shared',
#  'facebook',
#  'event',
#  'hosted',
#  'resisters',
#  'page',
#  'page',
#  'also',
#  'previously',
#  'ira',
#  'account',
#  'one',
#  'admins',
#  'seven',
#  'minutes',
#  'discoveries',
#  'helped',
#  'us',
#  'uncover',
#  'inauthentic',
#  'accounts',
#  'disabled',
#  'today',
#  'resisters',
#  'page',
#  'also',
#  'created',
#  'facebook',
#  'event',
#  'protest',
#  'august',
#  '10',
#  '12',
#  'enlisted',
#  'support',
#  'real',
#  'people',
#  'event',
#  '–',
#  'unite',
#  'right',
#  '2',
#  '–',
#  'dc',
#  '–',
#  'scheduled',
#  'protest',
#  'august',
#  'unite',
#  'right',
#  'event',
#  'washington',
#  'inauthentic',
#  'admins',
#  'resisters',
#  'page',
#  'connected',
#  'admins',
#  'five',
#  'legitimate',
#  'pages',
#  'co-host',
#  'event',
#  'legitimate',
#  'pages',
#  'unwittingly',
#  'helped',
#  'build',
#  'interest',
#  'unite',
#  'right',
#  '2',
#  '–',
#  'dc',
#  'posted',
#  'information',
#  'transportation',
#  'materials',
#  'locations',
#  'people',
#  'could',
#  'get',
#  'protests',
#  'disabled',
#  'event',
#  'earlier',
#  'today',
#  'reached',
#  'admins',
#  'five',
#  'pages',
#  'update',
#  'happened',
#  'afternoon',
#  'begin',
#  'informing',
#  'approximately',
#  '2,600',
#  'users',
#  'interested',
#  'event',
#  '600',
#  'users',
#  'said',
#  'attend',
#  'happened',
#  'facts',
#  'work',
#  'closely',
#  'others',
#  'continue',
#  'investigation',
#  'hope',
#  'get',
#  'new',
#  'information',
#  'law',
#  'enforcement',
#  'companies',
#  'better',
#  'understand',
#  'happened',
#  '—',
#  'share',
#  'additional',
#  'findings',
#  'law',
#  'enforcement',
#  'congress',
#  'however',
#  'may',
#  'never',
#  'able',
#  'identify',
#  'source',
#  'level',
#  'confidence',
#  'naming',
#  'ira',
#  'last',
#  'year',
#  'see',
#  'alex',
#  'stamos',
#  'post',
#  'attribution',
#  'really',
#  'hard',
#  'seeing',
#  'real',
#  'benefits',
#  'working',
#  'outside',
#  'experts',
#  'partners',
#  'like',
#  'atlantic',
#  'council',
#  'provided',
#  'invaluable',
#  'help',
#  'identifying',
#  'bad',
#  'actors',
#  'analyzing',
#  'behavior',
#  'across',
#  'internet',
#  'based',
#  'leads',
#  'recent',
#  'us',
#  'department',
#  'justice',
#  'indictment',
#  'atlantic',
#  'council',
#  'identified',
#  'facebook',
#  'group',
#  'roughly',
#  '4,000',
#  'members',
#  'created',
#  'russian',
#  'government',
#  'actors',
#  'dormant',
#  'since',
#  'disabled',
#  'group',
#  'admins',
#  'last',
#  'year',
#  'groups',
#  'typically',
#  'persist',
#  'facebook',
#  'even',
#  'admins',
#  'disabled',
#  'chose',
#  'remove',
#  'group',
#  'protect',
#  'privacy',
#  'members',
#  'advance',
#  'report',
#  'atlantic',
#  'council',
#  'plans',
#  'publish',
#  'soon',
#  'concludes',
#  'analysis',
#  'follow',
#  'report',
#  'coming',
#  'weeks',
#  'analysis',
#  'pages',
#  'accounts',
#  'profiles',
#  'disabled',
#  'today',
#  'july',
#  '31',
#  '2018',
#  'much',
#  'companies',
#  'know',
#  'behind',
#  'cyber',
#  'threats',
#  'alex',
#  'stamos',
#  'chief',
#  'security',
#  'officer',
#  'deciding',
#  'publicly',
#  'link',
#  'suspicious',
#  'activity',
#  'specific',
#  'organization',
#  'government',
#  'individual',
#  'challenge',
#  'governments',
#  'many',
#  'companies',
#  'face',
#  'last',
#  'year',
#  'said',
#  'russia-based',
#  'internet',
#  'research',
#  'agency',
#  'ira',
#  'behind',
#  'much',
#  'abuse',
#  'found',
#  'around',
#  '2016',
#  'election',
#  'today',
#  'shutting',
#  '32',
#  'pages',
#  'accounts',
#  'engaged',
#  'coordinated',
#  'inauthentic',
#  'behavior',
#  'without',
#  'saying',
#  'specific',
#  'group',
#  'country',
#  'responsible',
#  'process',
#  'attributing',
#  'observed',
#  'activity',
#  'particular',
#  'threat',
#  'actors',
#  'much',
#  'debated',
#  'academics',
#  'within',
#  'intelligence',
#  'community',
#  'modern',
#  'intelligence',
#  'agencies',
#  'use',
#  'internal',
#  'guidelines',
#  'help',
#  'consistently',
#  'communicate',
#  'findings',
#  'policymakers',
#  'public',
#  'companies',
#  'comparison',
#  'operate',
#  'relatively',
#  'limited',
#  'information',
#  'outside',
#  'sources',
#  '—',
#  'though',
#  'get',
#  'involved',
#  'detecting',
#  'investigating',
#  'kind',
#  'misuse',
#  'also',
#  'need',
#  'clear',
#  'consistent',
#  'ways',
#  'confront',
#  'communicate',
#  'issues',
#  'head',
#  'determining',
#  'behind',
#  'action',
#  'first',
#  'challenge',
#  'figuring',
#  'type',
#  'entity',
#  'attributing',
#  'responsibility',
#  'harder',
#  'might',
#  'sound',
#  'standard',
#  'traditional',
#  'security',
#  'attacks',
#  'information',
#  'operations',
#  'conducted',
#  'using',
#  'commercial',
#  'infrastructure',
#  'computers',
#  'belonging',
#  'innocent',
#  'people',
#  'compromised',
#  'result',
#  'simple',
#  'techniques',
#  'like',
#  'blaming',
#  'owner',
#  'ip',
#  'address',
#  'used',
#  'register',
#  'malicious',
#  'account',
#  'usually',
#  'sufficient',
#  'accurately',
#  'determine',
#  'responsible',
#  'instead',
#  'try',
#  'link',
#  'suspicious',
#  'activity',
#  'individual',
#  'group',
#  'primary',
#  'operational',
#  'responsibility',
#  'malicious',
#  'action',
#  'potentially',
#  'associate',
#  'multiple',
#  'campaigns',
#  'one',
#  'set',
#  'actors',
#  'study',
#  'abuse',
#  'systems',
#  'take',
#  'appropriate',
#  'countermeasures',
#  'tie',
#  'specific',
#  'actor',
#  'real-world',
#  'sponsor',
#  'could',
#  'include',
#  'political',
#  'organization',
#  'nation-state',
#  'non-political',
#  'entity',
#  'relationship',
#  'malicious',
#  'actors',
#  'real-world',
#  'sponsors',
#  'difficult',
#  'determine',
#  'practice',
#  'especially',
#  'activity',
#  'sponsored',
#  'nation-states',
#  'seminal',
#  'paper',
#  'topic',
#  'jason',
#  'healey',
#  'described',
#  'spectrum',
#  'measure',
#  'degree',
#  'state',
#  'responsibility',
#  'cyber',
#  'attacks',
#  'included',
#  '10',
#  'discrete',
#  'steps',
#  'ranging',
#  'state-prohibited',
#  'state',
#  'actively',
#  'stops',
#  'attacks',
#  'originating',
#  'territory',
#  'state-integrated',
#  'attackers',
#  'serve',
#  'fully',
#  'integrated',
#  'resources',
#  'national',
#  'government',
#  'framework',
#  'helpful',
#  'looking',
#  'two',
#  'major',
#  'organized',
#  'attempts',
#  'interfere',
#  '2016',
#  'us',
#  'election',
#  'facebook',
#  'found',
#  'date',
#  'one',
#  'set',
#  'actors',
#  'used',
#  'hacking',
#  'techniques',
#  'steal',
#  'information',
#  'email',
#  'accounts',
#  '—',
#  'contacted',
#  'journalists',
#  'using',
#  'social',
#  'media',
#  'encourage',
#  'publish',
#  'stories',
#  'stolen',
#  'data',
#  'based',
#  'investigation',
#  'information',
#  'provided',
#  'us',
#  'government',
#  'concluded',
#  'work',
#  'responsibility',
#  'groups',
#  'tied',
#  'gru',
#  'russian',
#  'military',
#  'intelligence',
#  'recent',
#  'special',
#  'counsel',
#  'indictment',
#  'gru',
#  'officers',
#  'supports',
#  'assessment',
#  'case',
#  'would',
#  'consider',
#  'actions',
#  'state-integrated',
#  'healey',
#  'spectrum',
#  'major',
#  'organized',
#  'effort',
#  'include',
#  'traditional',
#  'cyber',
#  'attacks',
#  'instead',
#  'designed',
#  'sow',
#  'division',
#  'using',
#  'social',
#  'media',
#  'based',
#  'investigations',
#  'assessed',
#  'high',
#  'confidence',
#  'group',
#  'part',
#  'ira',
#  'public',
#  'debate',
#  'relationship',
#  'ira',
#  'russian',
#  'government',
#  '—',
#  'though',
#  'seem',
#  'conclude',
#  'activity',
#  'state-encouraged',
#  'state-ordered',
#  'using',
#  'healey',
#  'definitions',
#  'four',
#  'methods',
#  'attribution',
#  'academics',
#  'written',
#  'variety',
#  'methods',
#  'attributing',
#  'activity',
#  'cyber',
#  'actors',
#  'purposes',
#  'simplify',
#  'methods',
#  'attribution',
#  'model',
#  'four',
#  'general',
#  'categories',
#  'appropriate',
#  'government',
#  'organizations',
#  'believe',
#  'used',
#  'companies',
#  'political',
#  'motivations',
#  'model',
#  ...]

# %%
from nltk.probability import FreqDist
freq = FreqDist(word_sent)
freq
# Out:
# FreqDist({'1,400': 1,
#           '10': 3,
#           '100': 1,
#           '11,000': 1,
#           '12': 1,
#           '150': 1,
#           '17': 1,
#           '2': 2,
#           '2,600': 1,
#           '2016': 5,
#           '2017': 2,
#           '2017.': 3,
#           '2018': 2,
#           '2018.': 2,
#           '290,000': 1,
#           '30': 1,
#           '31': 2,
#           '32': 2,
#           '4,000': 1,
#           '4,700': 1,
#           '600': 1,
#           '9,500': 1,
#           'able': 3,
#           'abuse': 6,
#           'academics': 2,
#           'account': 3,
#           'accounts': 21,
#           'accurately': 1,
#           'achieve': 1,
#           'across': 1,
#           'action': 3,
#           'actions': 3,
#           'actively': 1,
#           'activity': 11,
#           'actor': 5,
#           'actors': 16,
#           'ad': 1,
#           'additional': 1,
#           'address': 1,
#           'addresses': 2,
#           'administrator': 1,
#           'admins': 6,
#           'ads': 4,
#           'advance': 1,
#           'adversaries': 1,
#           'afternoon': 1,
#           'agencies': 2,
#           'agency': 2,
#           'ago': 1,
#           'alex': 2,
#           'allowed': 2,
#           'also': 4,
#           'always': 1,
#           'analysis': 2,
#           'analytical': 1,
#           'analyze': 1,
#           'analyzing': 1,
#           'applying': 1,
#           'appropriate': 4,
#           'approximately': 3,
#           'april': 1,
#           'arms': 1,
#           'around': 2,
#           'aspects': 1,
#           'assessed': 1,
#           'assessment': 4,
#           'associate': 1,
#           'atlantic': 4,
#           'attackers': 1,
#           'attacks': 4,
#           'attempts': 2,
#           'attend': 2,
#           'attending': 2,
#           'attribute': 2,
#           'attributing': 3,
#           'attribution': 13,
#           'august': 2,
#           'authentic': 1,
#           'authorities': 1,
#           'available': 1,
#           'aztlan': 1,
#           'back': 2,
#           'bad': 5,
#           'ban': 1,
#           'based': 4,
#           'begin': 1,
#           'behalf': 1,
#           'behavior': 8,
#           'behind': 9,
#           'believe': 6,
#           'belonging': 1,
#           'benefits': 1,
#           'best': 2,
#           'better': 4,
#           'black': 1,
#           'blaming': 1,
#           'build': 1,
#           'campaigns': 1,
#           'canadian': 1,
#           'capabilities': 2,
#           'careful': 2,
#           'case': 2,
#           'categories': 1,
#           'certainty': 1,
#           'challenge': 2,
#           'challenges': 1,
#           'challenging': 1,
#           'change': 1,
#           'changes': 1,
#           'changing': 1,
#           'chief': 1,
#           'chose': 1,
#           'clear': 2,
#           'closely': 2,
#           'co-host': 1,
#           'coincidences': 1,
#           'collaboration': 1,
#           'coming': 1,
#           'command': 1,
#           'comment': 1,
#           'commercial': 1,
#           'communicate': 2,
#           'community': 2,
#           'companies': 10,
#           'compare': 1,
#           'comparison': 1,
#           'compatible': 1,
#           'completed': 1,
#           'compromise': 1,
#           'compromised': 1,
#           'computers': 1,
#           'conceal': 1,
#           'conclude': 1,
#           'concluded': 1,
#           'concludes': 1,
#           'conducted': 1,
#           'confidence': 5,
#           'confidently': 1,
#           'confront': 1,
#           'congress': 3,
#           'connect': 1,
#           'connected': 1,
#           'connection': 1,
#           'connections': 2,
#           'consider': 1,
#           'consistent': 3,
#           'consistently': 1,
#           'constantly': 2,
#           'contacted': 1,
#           'content': 6,
#           'continue': 2,
#           'control': 1,
#           'controlled': 1,
#           'coordinated': 4,
#           'coordination': 2,
#           'copying': 1,
#           'could': 5,
#           'council': 4,
#           'counsel': 1,
#           'countermeasures': 1,
#           'country': 1,
#           'cover': 1,
#           'covered': 1,
#           'created': 8,
#           'creating': 1,
#           'cyber': 6,
#           'cybersecurity': 1,
#           'data': 2,
#           'date': 1,
#           'dc': 2,
#           'debate': 1,
#           'debated': 1,
#           'deciding': 1,
#           'definitions': 1,
#           'degree': 1,
#           'department': 1,
#           'described': 1,
#           'designed': 1,
#           'despite': 1,
#           'details': 2,
#           'detect': 1,
#           'detecting': 1,
#           'determination': 1,
#           'determine': 2,
#           'determined': 1,
#           'determining': 1,
#           'differences': 1,
#           'difficult': 1,
#           'digital': 1,
#           'direct': 1,
#           'disabled': 8,
#           'disclosed': 1,
#           'discourse': 1,
#           'discoveries': 1,
#           'discovery': 1,
#           'discrete': 1,
#           'discuss': 1,
#           'discussed': 1,
#           'disseminated': 1,
#           'distribution': 1,
#           'division': 1,
#           'dollars': 1,
#           'done': 1,
#           'dormant': 1,
#           'due': 2,
#           'earlier': 1,
#           'earliest': 1,
#           'early': 1,
#           'easy': 1,
#           'effort': 2,
#           'efforts': 1,
#           'eight': 1,
#           'election': 3,
#           'elections': 1,
#           'elevation': 1,
#           'email': 1,
#           'encourage': 1,
#           'enforcement': 7,
#           'enforcing': 1,
#           'engaged': 2,
#           'enlisted': 1,
#           'enough': 1,
#           'entity': 2,
#           'especially': 3,
#           'evaluation': 1,
#           'even': 2,
#           'event': 7,
#           'events': 2,
#           'ever': 1,
#           'every': 1,
#           'evidence': 7,
#           'evolve': 1,
#           'example': 4,
#           'examples': 2,
#           'exfiltration': 1,
#           'expected': 2,
#           'experts': 1,
#           'exploitation': 1,
#           'face': 3,
#           'facebook': 16,
#           'facts': 3,
#           'far': 3,
#           'fewer': 1,
#           'figuring': 1,
#           'find': 2,
#           'findings': 3,
#           'firm': 3,
#           'first': 3,
#           'five': 2,
#           'follow': 1,
#           'followed': 2,
#           'followers': 2,
#           'following': 1,
#           'foreign': 1,
#           'forensic': 1,
#           'forensics': 4,
#           'forums': 1,
#           'found': 8,
#           'four': 2,
#           'framework': 3,
#           'fully': 1,
#           'fundamental': 1,
#           'gathered': 1,
#           'general': 1,
#           'geographic': 1,
#           'get': 3,
#           'give': 2,
#           'given': 3,
#           'gleicher': 1,
#           'goal': 1,
#           'goals': 1,
#           'going': 1,
#           'government': 7,
#           'governments': 1,
#           'greater': 1,
#           'group': 12,
#           'groups': 3,
#           'gru': 2,
#           'guidelines': 1,
#           'hacking': 1,
#           'half': 1,
#           'happen': 1,
#           'happened': 3,
#           'hard': 1,
#           'harder': 3,
#           'head': 2,
#           'healey': 3,
#           'heavily': 2,
#           'help': 2,
#           'helped': 2,
#           'helpful': 1,
#           'helps': 1,
#           'high': 4,
#           'hope': 1,
#           'hosted': 1,
#           'however': 2,
#           'human': 1,
#           'identified': 3,
#           'identify': 4,
#           'identifying': 1,
#           'identities': 3,
#           'identity': 1,
#           'importance': 1,
#           'important': 1,
#           'improve': 2,
#           'improved': 1,
#           'inauthentic': 7,
#           'incident': 2,
#           'include': 2,
#           'included': 1,
#           'including': 4,
#           'independently': 1,
#           'indicates': 1,
#           'indicators': 1,
#           'indictment': 2,
#           'individual': 2,
#           'infer': 1,
#           'inferred': 1,
#           'influence': 1,
#           'information': 13,
#           'informing': 1,
#           'infrastructure': 3,
#           'initial': 1,
#           'innocent': 1,
#           'instagram': 5,
#           'instance': 1,
#           'instead': 2,
#           'insufficient': 2,
#           'integrated': 1,
#           'intelligence': 5,
#           'intend': 1,
#           'interacting': 1,
#           'interactions': 1,
#           'interest': 1,
#           'interested': 3,
#           'interfere': 1,
#           'internal': 1,
#           'internet': 4,
#           'invaluable': 1,
#           'invested': 1,
#           'investigating': 1,
#           'investigation': 5,
#           'investigations': 1,
#           'investing': 1,
#           'involved': 2,
#           'iocs': 2,
#           'ip': 3,
#           'ira': 22,
#           'issues': 1,
#           'jason': 1,
#           'journalists': 1,
#           'july': 2,
#           'june': 1,
#           'justice': 1,
#           'kind': 4,
#           'know': 4,
#           'known': 4,
#           'lab': 1,
#           'lack': 3,
#           'large': 1,
#           'largest': 1,
#           'last': 8,
#           'latest': 1,
#           'law': 7,
#           'leads': 4,
#           'learned': 1,
#           'least': 1,
#           'left': 1,
#           'legitimate': 3,
#           'lengths': 1,
#           'lessons': 1,
#           'level': 1,
#           'like': 2,
#           'limitations': 1,
#           'limited': 1,
#           'link': 2,
#           'linkage': 1,
#           'links': 1,
#           'location': 1,
#           'locations': 1,
#           'looking': 2,
#           'made': 1,
#           'major': 2,
#           'make': 3,
#           'malicious': 3,
#           'many': 2,
#           'march': 1,
#           'materials': 1,
#           'may': 5,
#           'meantime': 1,
#           'measure': 1,
#           'measured': 1,
#           'media': 2,
#           'members': 2,
#           'mentioned': 1,
#           'methods': 3,
#           'might': 2,
#           'military': 1,
#           'mindful': 1,
#           'minutes': 1,
#           'mislead': 1,
#           'mistake': 1,
#           'misuse': 1,
#           'misusing': 1,
#           'model': 2,
#           'modern': 1,
#           'morning': 1,
#           'motivations': 4,
#           'much': 10,
#           'multiple': 1,
#           'named': 1,
#           'naming': 1,
#           'nathaniel': 1,
#           'nation-state': 2,
#           'nation-states': 2,
#           'national': 1,
#           'need': 3,
#           'needed': 1,
#           'networks': 1,
#           'never': 2,
#           'new': 3,
#           'next': 1,
#           'non-political': 1,
#           'nothing': 1,
#           'number': 1,
#           'obscure': 2,
#           'observe': 1,
#           'observed': 1,
#           'offensive': 1,
#           'officer': 1,
#           'officers': 1,
#           'often': 1,
#           'one': 11,
#           'ongoing': 1,
#           'open': 1,
#           'operate': 1,
#           'operating': 1,
#           'operational': 2,
#           'operations': 1,
#           'organic': 1,
#           'organization': 4,
#           'organizations': 3,
#           'organized': 3,
#           'originating': 1,
#           'others': 3,
#           'outside': 2,
#           'owner': 1,
#           'page': 5,
#           'pages': 15,
#           'paid': 2,
#           'paper': 1,
#           'part': 3,
#           'particular': 1,
#           'parties': 1,
#           'partly': 2,
#           'partners': 2,
#           'past': 3,
#           'people': 6,
#           'performs': 1,
#           'persist': 1,
#           'persistent': 1,
#           'phone': 1,
#           'piece': 1,
#           'plan': 1,
#           'planned': 1,
#           'planning': 1,
#           'plans': 1,
#           'point': 1,
#           'policies': 1,
#           'policy': 1,
#           'policymakers': 1,
#           'political': 9,
#           'position': 1,
#           'possession': 1,
#           'possible': 3,
#           'post': 2,
#           'posted': 2,
#           'posts': 1,
#           'potential': 1,
#           'potentially': 1,
#           'practice': 1,
#           'prevent': 2,
#           'previous': 2,
#           'previously': 2,
#           'primary': 1,
#           'privacy': 1,
#           'private': 1,
#           'proactively': 1,
#           'procedures': 2,
#           'process': 1,
#           'profiles': 2,
#           'protect': 1,
#           'protest': 2,
#           'protests': 2,
#           'provide': 6,
#           'provided': 2,
#           'providing': 2,
#           'public': 9,
#           'publicly': 3,
#           'publish': 3,
#           'purposes': 1,
#           'race': 1,
#           'ran': 1,
#           'ranging': 1,
#           'reached': 1,
#           'real': 2,
#           'real-world': 2,
#           'really': 1,
#           'recent': 2,
#           'recognize': 1,
#           'reconnaissance': 1,
#           'register': 1,
#           'relationship': 2,
#           'relatively': 1,
#           'rely': 1,
#           'remaining': 1,
#           'remove': 1,
#           'removed': 3,
#           'report': 3,
#           'reported': 1,
#           'require': 1,
#           'requires': 1,
#           'research': 4,
#           'resisters': 3,
#           'resisters.': 1,
#           'resources': 1,
#           'responsibility': 4,
#           'responsible': 2,
#           'responsibly': 1,
#           'result': 2,
#           'results': 1,
#           'reviewing': 1,
#           'right': 4,
#           'roughly': 1,
#           'run': 1,
#           'russia-based': 1,
#           'russian': 4,
#           'russian-based': 1,
#           'said': 3,
#           'sample': 2,
#           'saw': 2,
#           'say': 1,
#           'saying': 1,
#           'scheduled': 1,
#           'secrets': 1,
#           'security': 4,
#           'see': 2,
#           'seeing': 1,
#           'seem': 1,
#           'seemingly': 1,
#           'seen': 2,
#           'seminal': 1,
#           'separate': 3,
#           'serve': 1,
#           'services': 1,
#           'set': 5,
#           'seven': 2,
#           'several': 1,
#           'share': 1,
#           'shared': 3,
#           'sharing': 3,
#           'shutting': 1,
#           'signals': 1,
#           'signs': 1,
#           'simple': 1,
#           'simplify': 1,
#           'since': 2,
#           'situations': 1,
#           'small': 1,
#           'social': 2,
#           'software': 1,
#           'solely': 1,
#           'something': 2,
#           'sometimes': 5,
#           'soon': 1,
#           'sound': 1,
#           'source': 1,
#           'sources': 2,
#           'sow': 1,
#           'special': 1,
#           'specific': 8,
#           'spectrum': 2,
#           'sponsor': 1,
#           'sponsored': 1,
#           'sponsors': 1,
#           'spoof': 1,
#           'stages': 1,
#           'stamos': 2,
#           'standard': 1,
#           'state': 2,
#           'state-encouraged': 1,
#           'state-integrated': 2,
#           'state-ordered': 1,
#           'state-prohibited': 1,
#           'steal': 1,
#           'steps': 1,
#           'still': 3,
#           'stolen': 2,
#           'stop': 1,
#           'stops': 1,
#           'stories': 1,
#           'strong': 1,
#           'stronger': 1,
#           'study': 1,
#           'studying': 1,
#           'sufficient': 1,
#           'suggest': 1,
#           'support': 2,
#           'supports': 1,
#           'suspicious': 2,
#           'systems': 1,
#           'tactics': 1,
#           'take': 1,
#           'taken': 1,
#           'tech': 1,
#           'technical': 5,
#           'techniques': 6,
#           'technology': 3,
#           'territory': 1,
#           'thinking': 1,
#           'third': 1,
#           'though': 3,
#           'thousands': 1,
#           'threat': 4,
#           'threats': 4,
#           'tie': 2,
#           'tied': 1,
#           'time': 2,
#           'today': 7,
#           'told': 1,
#           'tools': 2,
#           'top': 1,
#           'topic': 1,
#           'total': 1,
#           'trace': 1,
#           'tracks': 1,
#           'traditional': 2,
#           'transportation': 1,
#           'treated': 1,
#           'true': 2,
#           'try': 1,
#           'ttps': 4,
#           'turn': 2,
#           'two': 2,
#           'type': 1,
#           'typically': 1,
#           'uncover': 1,
#           'uncovered': 1,
#           'understand': 2,
#           'unique': 1,
#           'unite': 3,
#           'unrelated': 1,
#           'unwittingly': 1,
#           'update': 2,
#           'upon': 1,
#           'us': 10,
#           'use': 2,
#           'used': 5,
#           'users': 3,
#           'using': 5,
#           'usually': 1,
#           'value': 1,
#           'variety': 1,
#           'violate': 2,
#           'vpns': 1,
#           'want': 1,
#           'warriors': 1,
#           'washington': 2,
#           'ways': 1,
#           'week': 1,
#           'weeks': 2,
#           'well': 2,
#           'well-funded': 1,
#           'went': 1,
#           'whoever': 1,
#           'widely': 1,
#           'wishful': 1,
#           'within': 1,
#           'without': 1,
#           'work': 3,
#           'working': 3,
#           'would': 2,
#           'written': 1,
#           'year': 8,
#           'zero': 2,
#           '–': 4,
#           '—': 8})

# %%
from heapq import nlargest

# %%
nlargest(10, freq, key=freq.get)
# Out:
# ['ira',
#  'accounts',
#  'facebook',
#  'actors',
#  'pages',
#  'information',
#  'attribution',
#  'group',
#  'one',
#  'activity']

# %%
from collections import defaultdict
ranking = defaultdict(int)

for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
            
ranking
# Out:
# defaultdict(int,
#             {0: 90,
#              1: 67,
#              2: 39,
#              3: 46,
#              4: 10,
#              5: 85,
#              6: 59,
#              7: 8,
#              8: 14,
#              9: 9,
#              10: 119,
#              11: 54,
#              12: 129,
#              13: 130,
#              14: 64,
#              15: 16,
#              16: 92,
#              17: 71,
#              18: 45,
#              19: 34,
#              20: 35,
#              21: 29,
#              22: 42,
#              23: 29,
#              24: 30,
#              25: 53,
#              26: 26,
#              27: 44,
#              28: 44,
#              29: 106,
#              30: 1,
#              31: 97,
#              32: 2,
#              33: 47,
#              34: 46,
#              35: 82,
#              36: 56,
#              37: 21,
#              38: 99,
#              39: 56,
#              40: 57,
#              41: 62,
#              42: 51,
#              43: 56,
#              44: 72,
#              45: 52,
#              46: 32,
#              47: 18,
#              48: 83,
#              49: 62,
#              50: 23,
#              51: 10,
#              52: 53,
#              53: 67,
#              54: 80,
#              55: 75,
#              56: 62,
#              57: 49,
#              58: 68,
#              59: 95,
#              60: 92,
#              61: 58,
#              62: 30,
#              63: 73,
#              64: 29,
#              65: 6,
#              66: 45,
#              67: 36,
#              68: 45,
#              69: 50,
#              70: 18,
#              71: 25,
#              72: 45,
#              73: 28,
#              74: 33,
#              75: 59,
#              76: 108,
#              77: 65,
#              78: 29,
#              79: 35,
#              80: 52,
#              81: 80,
#              82: 85,
#              83: 81,
#              84: 80,
#              85: 27,
#              86: 55,
#              87: 53,
#              88: 7,
#              89: 46,
#              90: 107,
#              91: 50,
#              92: 71,
#              93: 50,
#              94: 79,
#              95: 48,
#              96: 129,
#              97: 86,
#              98: 80,
#              99: 64,
#              100: 49,
#              101: 65,
#              102: 72,
#              103: 41,
#              104: 93,
#              105: 44,
#              106: 69,
#              107: 86,
#              108: 30,
#              109: 70,
#              110: 81,
#              111: 31,
#              112: 71,
#              113: 57,
#              114: 57,
#              115: 8})

# %%
sents_idx = nlargest(4, ranking, key=ranking.get)
sents_idx
# Out:
# [13, 12, 96, 10]

# %%
[sents[j] for j in sorted(sents_idx)]
# Out:
# ['It’s why we’re investing heavily in more people and better technology to prevent bad actors misusing Facebook — as well as working much more closely with law enforcement and other tech companies to better understand the threats we face.',
#  'Sample Content\n\xa0\nJuly 31, 2018\nWhat We’ve Found So Far\nBy Nathaniel Gleicher, Head of Cybersecurity Policy\nAbout two weeks ago we identified the first of eight Pages and 17 profiles on Facebook, as well as seven Instagram accounts, that violate our ban on coordinated inauthentic behavior.',
#  'We removed all of them this morning once we’d completed our initial investigation and shared the information with US law enforcement agencies, Congress, other technology companies, and the\xa0Atlantic Council’s Digital Forensic Research Lab, a research organization that helps us identify and analyze abuse on Facebook.',
#  'Applying the Framework to Our New Discovery\nHere is how we use this framework to discuss attribution of the accounts and Pages we removed today:\n\nAs mentioned, we will not provide an assessment of the political motivations of the group behind this activity.']

# %%
def summarize(text, n):
    sents = sent_tokenize(text)
    
    assert n <= len(sents)
    word_sent = word_tokenize(text.lower())
    _stopwords = set(stopwords.words('english') + list(punctuation))
    
    word_sent=[word for word in word_sent if word not in _stopwords]
    freq = FreqDist(word_sent)
    
    
    ranking = defaultdict(int)
    
    for i,sent in enumerate(sents):
        for w in word_tokenize(sent.lower()):
            if w in freq:
                ranking[i] += freq[w]
             
        
    sents_idx = nlargest(n, ranking, key=ranking.get)
    return [sents[j] for j in sorted(sents_idx)]

# %%
summarize(text,4)
# Out:
# ['It’s why we’re investing heavily in more people and better technology to prevent bad actors misusing Facebook — as well as working much more closely with law enforcement and other tech companies to better understand the threats we face.',
#  'We removed all of them this morning once we’d completed our initial investigation and shared the information with US law enforcement agencies, Congress, other technology companies, and the\xa0Atlantic Council’s Digital Forensic Research Lab, a research organization that helps us identify and analyze abuse on Facebook.',
#  'The most followed Facebook Pages were “Aztlan Warriors,” “Black Elevation,” “Mindful Being,” and “Resisters.” The remaining Pages had between zero and 10 followers, and the Instagram accounts had zero followers.',
#  'It’s why we’re following up on thousands of leads, including information from law enforcement and lessons we learned from last year’s IRA investigation.']
